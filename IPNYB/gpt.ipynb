# %%
import pandas as pd
import numpy as np
import random
import openai
import os
import re
###############################################################################
#0. API Key
###############################################################################
openai.api_key = "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"

###############################################################################
# 1. Configure OpenAI
###############################################################################
# Replace this with a safer method (e.g., environment variable) in production
# openai.api_key = "YOUR_OPENAI_API_KEY"

def test_api_access():
    """
    Attempts to list OpenAI models to confirm that the API key is valid.
    Prints a success or failure message, along with a list of available models if successful.
    """
    try:
        models = openai.Model.list()
        # print("Access to OpenAI API successful! Available models:")
        # for model in models['data']:
        #     print(f" - {model['id']}")
    except Exception as e:
        print("Failed to access the OpenAI API:")
        print(e)

###############################################################################
# 2. Core LLM function (using OpenAI GPT models)
###############################################################################
def generate_gpt(prompt, model_name="gpt-3.5-turbo"):
    """
    Sends a prompt to the OpenAI GPT (ChatCompletion) and returns the response text.
    """
    try:
        response = openai.ChatCompletion.create(
            model=model_name,
            messages=[{"role": "user", "content": prompt}],
            temperature=0.7,
        )
        return response.choices[0].message["content"]
    except Exception as e:
        print(f"An error occurred with the GPT call: {e}")
        return None

###############################################################################
# 3. Extract first word utility
###############################################################################
def extract_word_from_response(response_text):
    """
    Extracts and returns the first word-like token from the response_text.
    Returns None if no valid word is found or if response_text is None.
    """
    if response_text is None:
        return None
    cleaned_text = re.sub(r"[^\w'-]", " ", response_text)
    word = re.search(r'\b\w+\b', cleaned_text)
    return word.group(0) if word else None

###############################################################################
# 4. Few-shot example formatter
###############################################################################
def prompt_few_shot(data, Question_Type, num_examples):
    """
    Filters the dataset by Question_Type, samples up to num_examples,
    and formats them as example references to be appended to the main prompt.
    """
    filtered_df = data[data.iloc[:, 0] == Question_Type]
    if filtered_df.empty:
        return ""
    else:
        examples = filtered_df.sample(n=min(num_examples, len(filtered_df)))
        formatted_examples = ""
        for _, row in examples.iterrows():
            correct_choice = row[f"Choice_{row['Correct_Answer']}"]
            formatted_examples += f"For Example:\n"
            formatted_examples += f"Question: {row['Instruction']}\n"
            formatted_examples += f"A) {row['Choice_1']}\n"
            formatted_examples += f"B) {row['Choice_2']}\n"
            formatted_examples += f"C) {row['Choice_3']}\n"
            formatted_examples += f"Correct Answer: {correct_choice}\n"
            formatted_examples += (
                f"Explanation: Task difficulty of this question is {row['Task_Difficulty']}, "
                f"and word difficulty of this question is {row['Word_Difficulty']}\n\n"
                f"This is few_shot examples, generate different questions from these examples\n\n"
            )
        return formatted_examples

###############################################################################
# 5. Chain-of-thought (single-prompt)
###############################################################################
def prompt_chain_of_thought():
    """
    Appends a general chain-of-thought instruction.
    No CSV examples are used—just an instruction telling the model
    to 'think aloud' before finalizing the question.
    """
    # Ensuring we keep the final question in a parseable format
    chain_instruction = f"""
--- Chain of Thought ---
Please think aloud, and provide your reasoning before providing the final 3-choice question.
Include your reasoning in the final output as well.

Finally, PRESENT the final question in this format:
Question: [your question]
A) [option A]
B) [option B]
C) [option C]
Correct Answer: [the correct choice]
"""
    return chain_instruction

###############################################################################
# 6A. "Fake" single-prompt chain_of_thought_plus_sequential
###############################################################################
def prompt_chain_of_thought_plus_sequential(question_type, word_difficulty, task_difficulty):
    """
    A multi-step chain-of-thought approach. The final prompt instructs the model
    to create the MCQ in 3 steps (selecting words, drafting a question, adding distractors),
    each time showing its chain-of-thought reasoning.
    """
    multi_step_instructions = f"""
--- Chain of Thought + Sequential Steps ---

We want a 3-choice question for question_type={question_type}.
Word difficulty = {word_difficulty}, Task difficulty = {task_difficulty}.

Please follow these steps in your final output (all in one go):

Step 1: List three suitable Grade 3-5 words that illustrate the morphological concept
         (prefix, suffix, root, etc. depending on question_type).
         Show reasoning why each word is appropriate.
         Then select exactly ONE of them.

Step 2: Using the single selected word, generate a DRAFT 3-choice question.
        Provide chain-of-thought: i.e., explain your reasoning for how the question is framed.

Step 3: Add one correct answer choice and two distractors.
        Provide chain-of-thought for how each distractor might trick the student,
        and confirm which is correct.

Finally, PRESENT the final question in this format:
Question: [your question]
A) [option A]
B) [option B]
C) [option C]
Correct Answer: [the correct choice]

Be explicit with your chain-of-thought reasoning for each step,
but ensure the final output ends with the standard question format shown above.
    """
    return multi_step_instructions


def parse_chosen_word(response_text):
    """
    Try to parse the chosen word from the multi-step response text.
    We look for specific cues like 'Final word:' or 'Chosen word:' or
    text like 'I would choose "XYZ".'
    If none of these are found, we fall back to a naive approach.
    """
    if not response_text:
        return None

    # 0) Look for something like: Final word choice: XYZ
    match = re.search(r'(?i)final word choice:\s*([A-Za-z\'\-]+)', response_text)
    if match:
        return match.group(1)    
        
    # 1) Look for something like: Final word: XYZ
    match = re.search(r'(?i)final word:\s*([A-Za-z\'\-]+)', response_text)
    if match:
        return match.group(1)

    # 2) Look for something like: Chosen word: XYZ
    match = re.search(r'(?i)chosen word:\s*([A-Za-z\'\-]+)', response_text)
    if match:
        return match.group(1)

    # 3) Look for: I would choose "XYZ"
    match = re.search(r'(?i)i would choose\s+"([^"]+)"', response_text)
    if match:
        return match.group(1)

    # 4) Look for: I choose "XYZ"
    match = re.search(r'(?i)i choose\s+"([^"]+)"', response_text)
    if match:
        return match.group(1)

    # 5) As a last resort, do a naive approach: first alphabetic word.
    cleaned_text = re.sub(r"[^\w'-]", " ", response_text)
    first_word = re.search(r'\b[a-zA-Z\'\-]+\b', cleaned_text)
    return first_word.group(0) if first_word else None


###############################################################################
# 6B. REAL multi-step approach: chain_of_thought_plus_sequential_rl
###############################################################################
def prompt_chain_of_thought_plus_sequential_rl(question_type, word_difficulty, task_difficulty, forbidden_list=None, **kwargs):
    """
    TRUE multi-step approach that calls GPT multiple times.

    Step 0 (New): We prepend an instruction prompt based on question_type.
    Step 1: We ask GPT for 3 suitable words + chain-of-thought, then parse out
            the chosen word.
    Step 2: We feed that chosen word to GPT, ask for a draft 3-choice question
            (with chain-of-thought).
    Step 3: We ask GPT to add distractors & finalize the parseable question.

    Returns (final_text, the_word).
    """
        
    word_list = kwargs.get("word_list", None)
    if question_type in [4, 5] and word_list is None:
        raise ValueError("word_list is required for question_type 4 and 5")


    if forbidden_list is None:
        forbidden_list = []
        
    # ---------------------------
    # Define all question prompts
    # ---------------------------
    prompt_instruction_qt1 = (
        f"We want to generate a 3-choice question for a student learning about prefixes. "
        f"The word difficulty must be {word_difficulty} and task difficulty must be {task_difficulty}. "
        f"Be informed that ultimately, the question should ask the student to identify the prefix in a chosen word and provide "
        f"two incorrect choices along with the correct answer."
    )
    prompt_instruction_qt2 = (
        f"We want to generate a 3-choice question for a student learning about suffixes. "
        f"The word difficulty must be {word_difficulty} and task difficulty must be {task_difficulty}. "
        f"Be informed that ultimately, the question should ask the student to identify the suffix in the chosen word "
        f"and provide two incorrect choices along with the correct answer. "
    )
    prompt_instruction_qt3 = (
        f"We want to generate a 3-choice question for a student learning about root words. "
        f"The word difficulty must be {word_difficulty} and task difficulty must be {task_difficulty}. "
        f"Be informed that ultimately, the question should ask the student to identify the root word in the chosen word "
        f"and provide two incorrect choices along with the correct answer. "
    )
    prompt_instruction_qt4 = (
        f"We want to generate a 3-choice question for a student learning about morphemes. "
        f"The word difficulty must be {word_difficulty} and task difficulty must be {task_difficulty}. "
        f"Be informed that ultimately, the question should ask the student to identify the word that does NOT share "
        f"the same prefix as the others from the given words {word_list}. "
    )
    prompt_instruction_qt5 = (
        f"We want to generate a 3-choice question for a student learning about morphemes. "
        f"The word difficulty must be {word_difficulty} and task difficulty must be {task_difficulty}. "
        f"Be informed that ultimately, the question should ask the student to identify the word that does NOT share "
        f"the same suffix as the others from the given words {word_list}. "
    )
    prompt_instruction_qt6 = (
        f"We want to generate a 3-choice question for a student learning about word transformations. "
        f"The word difficulty must be {word_difficulty} and task difficulty must be {task_difficulty}. "
        f"Be informed that ultimately, the question should ask the student to transform the chosen word to a new meaning, "
        f"with two incorrect choices and one correct answer. "
    )
    prompt_instruction_qt7 = (
        f"We want to generate a 3-choice question for a student learning about affixed words. "
        f"The word difficulty must be {word_difficulty} and task difficulty must be {task_difficulty}. "
        f"Be informed that ultimately, the question should ask the student to select the correct meaning of the chosen word  "
        f"from three answer choices. "
    )
    # prompt_restriction used in qt8 is assumed defined elsewhere or can be set to an empty string if not needed.
    prompt_instruction_qt8 = (
        f"We want to generate a 3-choice question for a student learning about spelling based on morpheme meaning"
        f"{{prompt_restriction}} "
        f"The word difficulty must be {word_difficulty} and task difficulty must be {task_difficulty}. "
        f"Be informed that ultimately, the question should include a word with a suffix, provide two misspelled variations "
        f"and one correct spelling."
    )
    prompt_instruction_qt9 = (
        f"We want to generate a 3-choice question for a student learning to break affixed words into parts. "
        f"The word difficulty must be {word_difficulty} and task difficulty must be {task_difficulty}. "
        f"Be informed that ultimately, the question should ask the student to break the chosen word into its correct parts "
        f"(prefix, root, suffix) and provide two incorrect choices along with the correct answer."
    )
    prompt_instruction_qt10 = (
        f"We want to generate a 3-choice question for a student learning about prefixes. "
        f"The word difficulty must be {word_difficulty} and task difficulty must be {task_difficulty}. "
        f"Be informed that ultimately, the question should ask the student to select the correct definition of the prefix "
        f"in the chosen word from three answer choices."
    )
    prompt_instruction_qt11 = (
        f"We want to generate a 3-choice question for a student learning about root words in affixed words. "
        f"The word difficulty must be {word_difficulty} and task difficulty must be {task_difficulty}. "
        f"Be informed that ultimately, the question should ask the student to select the correct definition of the root word "
        f"in the chosen word from three answer choices."
    )
    prompt_instruction_qt12 = (
        f"We want to generate a 3-choice question for a student learning about suffixes. "
        f"The word difficulty must be {word_difficulty} and task difficulty must be {task_difficulty}. "
        f"Be informed that ultimately, the question should ask the student to select the correct definition or function of the suffix "
        f"in the chosen word from three answer choices."
    )
    prompt_instruction_qt13 = (
        f"We want to generate a 3-choice question for a student learning about morphologically complex words. "
        f"The word difficulty must be {word_difficulty} and task difficulty must be {task_difficulty}. "
        f"Be informed that ultimately, the question should ask the student to select the correct definition of the chosen word "
        f"based on its morphemes."
    )

    # -------------------------------------------------------
    # Map question_type to the corresponding prompt instruction
    # -------------------------------------------------------
    instructions_map = {
        1: prompt_instruction_qt1,
        2: prompt_instruction_qt2,
        3: prompt_instruction_qt3,
        4: prompt_instruction_qt4,
        5: prompt_instruction_qt5,
        6: prompt_instruction_qt6,
        7: prompt_instruction_qt7,
        8: prompt_instruction_qt8,
        9: prompt_instruction_qt9,
        10: prompt_instruction_qt10,
        11: prompt_instruction_qt11,
        12: prompt_instruction_qt12,
        13: prompt_instruction_qt13
    }

    # ---------------------------
    # Retrieve the question prompt
    # ---------------------------
    question_prompt_instruction = instructions_map.get(
        question_type,
        f"[No prompt defined for question_type={question_type}]"
    )

    
    
    
    # ---------------------------
    # Step 1: Pick Words
    # ---------------------------
    # We prepend the relevant instruction prompt here
    if question_type not in [4, 5]:
        step1_prompt = f"""
    {question_prompt_instruction}

    Step 1 (Pick Words):
    Question Type = {question_type}
    Word Difficulty = {word_difficulty}, Task Difficulty = {task_difficulty}

    Please list three suitable Grade 3-5 words that fit the morphological concept
    (prefix, suffix, root, etc.) for this Question Type: {question_type}. Have in mind that this word is going to be used for this instruction {question_prompt_instruction}. 
    Do NOT generate the whole question yet. In this step just generate and choose appropriate word considering what the question is about. Explain your chain-of-thought for each choice (why is it appropriate?).
    Then select exactly ONE of the three as the final word, and provide reasoning for it (think aloud).
    """
        step1_result = generate_gpt(step1_prompt)
        print(f"==> Step 1 result: {step1_result}\n")
        # Just do a naive parse: find "Chosen Word:" or something
        # If there's no consistent structure, we could guess or rely on a simpler approach
        chosen_word = parse_chosen_word(step1_result)

        # If we can't parse the chosen word, fallback
        if not chosen_word:
            chosen_word = "mysteryWord"

                
        # Single-check if chosen_word is in forbidden_list
        if chosen_word.lower() in [fw.lower() for fw in forbidden_list]:
            # Force a single re-ask with a "temp_prompt"
            conflict_prompt = (
                f"You gave the word '{chosen_word}', but it's in the forbidden list: {forbidden_list}.\n"
                f"Please choose a different word that meets the previously-defined criteria, and also is NOT in that list."
            )
            step1_result_2 = generate_gpt(conflict_prompt)
            chosen_word = parse_chosen_word(step1_result_2)
            if not chosen_word:
                chosen_word = "mysteryWord"
                    
        
    else:
        step1_prompt = f"""
    {question_prompt_instruction}

    Step 1 (Pick Words):
    Question Type = {question_type}
    Word Difficulty = {word_difficulty}, Task Difficulty = {task_difficulty}

    Have in mind that everything should be suitable for Grade 3-5 words that fit the morphological concept
    (prefix, suffix, root, etc.) for this Question Type: {question_type}. 
    You should only consider words that one of them does NOT share the same prefix as the others from the given words {word_list}. 
    Have in mind that this word is going to be used for this instruction {question_prompt_instruction}. 
    Do NOT generate the whole question yet. In this step just consider choosing the appropriate word considering what the question is about. 
    Explain your chain-of-thought for each choice (why is it appropriate?). 
    SKIP THIS STEP, AND MOVE FORWARD WITH STEP 2.
    """
        step1_result = generate_gpt(step1_prompt)
        print(f"==> Step 1 result: {step1_result}\n")
        # Just do a naive parse: find "Chosen Word:" or something
        # If there's no consistent structure, we could guess or rely on a simpler approach
        chosen_word = parse_chosen_word(step1_result)

        # If we can't parse the chosen word, fallback
        if not chosen_word:
            chosen_word = "mysteryWord"

        # # Single-check if chosen_word is in forbidden_list
        # if chosen_word.lower() in [fw.lower() for fw in forbidden_list]:
        #     # Force a single re-ask with a "temp_prompt"
        #     conflict_prompt = (
        #         f"You gave the word '{chosen_word}', but it's in the forbidden list: {forbidden_list}.\n"
        #         f"Please choose a different word that meets the previously-defined criteria, and also is NOT in that list."
        #     )
        #     step1_result_2 = generate_gpt(conflict_prompt)
        #     chosen_word = parse_chosen_word(step1_result_2)
        #     if not chosen_word:
        #         chosen_word = "mysteryWord"
                
    # ---------------------------
    # Step 2: Draft question
    # ---------------------------
    step2_prompt = f"""
    Step 2 (Draft Question):
    We have chosen the word: {chosen_word}.

    Now draft a 3-choice question based on the following instruction: {question_prompt_instruction}. Provide a chain-of-thought explaining
    how you formed the question, and provide the correct answer.

    Do NOT finalize the answer choices yet. Give the question text
    and placeholders for A/B/C. For instance:
    "Question: ... A) ... B) ... C) ..."

    """
    step2_result = generate_gpt(step2_prompt)
    # We'll accept step2_result as a partial question
    print(f"==> Step 2 result: {step2_result}\n")
    
    # ---------------------------
    # Step 3: Add distractors & finalize
    # ---------------------------
    step3_prompt = f"""
    Step 3 (Add Choices & Finalize):
    Based on the draft question and the correct answer you provided in the previous step:

    {step2_result}

    Update the TWO distractors with reasoning, considering the specified task difficulty of: {task_difficulty}. Provide chain-of-thought
    about how each distractor might trick the student, and confirm the correct answer.

    Finally, shuffle the answer choices and present the final question in a parseable format:
    Question: ...
    A) ...
    B) ...
    C) ...
    Correct Answer: ...
    Do NOT provide the reasonings in the above parseable format. Write them here, after everything is done.
    """
    step3_result = generate_gpt(step3_prompt)
    print(f"==> Step 3 result: {step3_result}\n")
    # The final text to parse is step3_result
    final_text = step3_result
    print(f"====== HERE IS THE FORBIDDEN_LIST: {forbidden_list}\n")
    return final_text, chosen_word


###############################################################################
# 7. NEW Strategy: chain_of_thought_plus_role_chain
###############################################################################
def prompt_chain_of_thought_plus_role_chain(question_type, word_difficulty, task_difficulty):
    """
    A multi-role chain-of-thought approach. The model is asked to produce an MCQ 
    (with exactly 3 choices) for a grade 3-5 audience, but does so by iterating 
    through three different 'roles' in its reasoning:

    Role 1) Teacher:
       - Think about how to instruct a Grade 3-5 student. 
       - Provide a suitable question and partial answer choices in plain, accessible language.
       - Make sure the question is neither too trivial nor too advanced for grades 3-5.
       - Provide your chain-of-thought on how you arrived at this version.

    Role 2) Student:
       - Evaluate the Teacher's question from a student’s perspective.
       - Check if any distractor is obviously or trivially wrong, or if the question is unclear.
       - Suggest if the question might be confusing or if it needs improvement.
       - Provide your chain-of-thought on how you analyzed the question.

    Role 3) Technometrician (or Psychometrician):
       - Verify that the question meets the morphological objective implied by question_type
         (e.g., identifying prefix/suffix, ensuring correct root word, etc.).
       - Check that the difficulty aligns with the stated word/task difficulty.
       - Offer final refinements if needed, then present the final version of the question 
         in a parseable format:

         Final Question: ...
         A) ...
         B) ...
         C) ...
         Correct Answer: ...

    The model should output the chain-of-thought for each role, followed by the final question.
    The final question must always end in the parseable format shown above. 
    """

    role_instructions = f"""
--- 3-Role Reasoning for a Grade 3-5 3-choice question ---

We want a 3-choice question for:
  question_type = {question_type}
  word_difficulty = {word_difficulty}
  task_difficulty = {task_difficulty}

You should act in all of the following three roles, one by one, and think aloud in each of them (provide reasonings):
==========
Roles & Instructions:
==========

(1) Teacher Role
  - Act as a Grade 3–5 teacher.
  - Propose a question that is suitable for a grade 3-5 student, focusing on the morphological concept 
    (prefix, suffix, root, etc.) relevant to question_type={question_type}.
  - Provide your chain-of-thought on how the question was formed (provide reasoning, or think aloud), 
    ensuring it's neither too trivial nor too advanced for grades 3–5.
  - Then pass along your question and partial choices to the next role.

(2) Student Role
  - Act as a Grade 3–5 student.
  - Read what the Teacher proposed. 
  - Comment if the question is confusing, or if any distractor is obviously incorrect.
  - Provide your chain-of-thought as a student (provide reasoning, or think aloud).
  - Then pass along your outputs to the next role.

(3) Technometrician Role
  - Act as a test-design specialist focusing on morphological objectives (prefix, suffix, root, etc.) 
    and checking alignment with word_difficulty={word_difficulty} & task_difficulty={task_difficulty}.
  - Evaluate the question from both Teacher and Student roles:
    - Are we accurately testing the morphological skill for question_type={question_type}?
    - Are the difficulty levels appropriate?
  - Provide final refinements if needed. Be strict if you can make the question or the distractors more aligned with what is asked.
  - Then present the finalized question in a parseable format, exactly as follows:

      Final Question: [refined question text here]
      A) [choice A]
      B) [choice B]
      C) [choice C]
      Correct Answer: [the correct choice]

    """

    return role_instructions


###############################################################################
# 8. Prompt Generators for Each Question Type
###############################################################################
def generate_prefix_prompt(word_difficulty, task_difficulty, data, prompting, words):  # question_type = 1
    if words:
        word_exclusion = f" and it must NOT be any of these words (case insensitive): {', '.join(words)}."
    else:
        word_exclusion = ""

    gen_prompt = (
        f"Please generate an English word that has a prefix{word_exclusion} "
        f"Its level of difficulty for grade 3-5 is {word_difficulty} out of 5.\n"
        f"Return your response in this exact format:\n"
        f"WORD: [your word]\n"
        f"EXPLANATION: [brief explanation why this word is appropriate]"
    )
    # -- 1) GPT call to pick a word
    result = generate_gpt(gen_prompt)
    word_match = re.search(r"WORD:\s*(\w+)", result or "")
    word = word_match.group(1) if word_match else None

    # -- 2) The main MCQ prompt (Zero-shot style)
    prompt = (
        f"Generate a 3-choice question for a student learning about prefixes. "
        f"The word is '{word}', with word difficulty {word_difficulty} and task difficulty {task_difficulty}. "
        f"The question should ask the student to identify the prefix in '{word}' and provide "
        f"two incorrect choices along with the correct answer. Please specify the correct answer."
    )
        
    # -- 3) Append optional prompting strategy
    if prompting == 'few_shot':
        prompt += prompt_few_shot(data, 1, 6)
        return prompt, word
    elif prompting == 'chain_of_thought':
        prompt += prompt_chain_of_thought()
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential':
        prompt += prompt_chain_of_thought_plus_sequential(1, word_difficulty, task_difficulty)
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential_rl':
        # Call the RL version, which returns final_text and chosen_word
        final_text, chosen_word = prompt_chain_of_thought_plus_sequential_rl(
            1, word_difficulty, task_difficulty, forbidden_list=words
        )
        return final_text, chosen_word
    elif prompting == 'chain_of_thought_plus_role_chain':
        prompt += prompt_chain_of_thought_plus_role_chain(1, word_difficulty, task_difficulty)
        return prompt, word
    else:
        # default zero-shot
        return prompt, word


def generate_suffix_prompt(word_difficulty, task_difficulty, data, prompting, words):  # question_type = 2
    if words:
        word_exclusion = f" and it must NOT be any of these words (case insensitive): {', '.join(words)}."
    else:
        word_exclusion = ""

    gen_prompt = (
        f"Please generate an English word that has a suffix{word_exclusion} "
        f"Its level of difficulty for grade 3-5 is {word_difficulty} out of 5.\n"
        f"Return your response in this exact format:\n"
        f"WORD: [your word]\n"
        f"EXPLANATION: [brief explanation why this word is appropriate]"
    )
    result = generate_gpt(gen_prompt)
    word_match = re.search(r"WORD:\s*(\w+)", result or "")
    word = word_match.group(1) if word_match else None

    prompt = (
        f"Generate a 3-choice question for a student learning about suffixes. "
        f"The word is '{word}', with word difficulty {word_difficulty} and task difficulty {task_difficulty}. "
        f"The question should ask the student to identify the suffix in '{word}' and provide two "
        f"incorrect choices along with the correct answer. Please specify the correct answer."
    )
    if prompting == 'few_shot':
        prompt += prompt_few_shot(data, 2, 6)
        return prompt, word
    elif prompting == 'chain_of_thought':
        prompt += prompt_chain_of_thought()
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential':
        prompt += prompt_chain_of_thought_plus_sequential(2, word_difficulty, task_difficulty)
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential_rl':
        final_text, chosen_word = prompt_chain_of_thought_plus_sequential_rl(
            2, word_difficulty, task_difficulty, forbidden_list=words
        )
        return final_text, chosen_word
    elif prompting == 'chain_of_thought_plus_role_chain':
        prompt += prompt_chain_of_thought_plus_role_chain(2, word_difficulty, task_difficulty)
        return prompt, word
    else:
        return prompt, word


def generate_root_word_prompt(word_difficulty, task_difficulty, data, prompting, words):  # question_type = 3
    if words:
        word_exclusion = f" and it must NOT be any of these words (case insensitive): {', '.join(words)}."
    else:
        word_exclusion = ""

    gen_prompt = (
        f"Please generate an English word that has a prefix or suffix{word_exclusion} "
        f"Its level of difficulty for grade 3-5 is {word_difficulty} out of 5.\n"
        f"Return your response in this exact format:\n"
        f"WORD: [your word]\n"
        f"EXPLANATION: [brief explanation why this word is appropriate]"
    )
    result = generate_gpt(gen_prompt)
    word_match = re.search(r"WORD:\s*(\w+)", result or "")
    word = word_match.group(1) if word_match else None

    prompt = (
        f"Generate a 3-choice question for a student learning about root words. "
        f"The word is '{word}', with word difficulty {word_difficulty} and task difficulty {task_difficulty}. "
        f"The question should ask the student to identify the root word in '{word}' and provide two "
        f"incorrect choices along with the correct answer. Clearly specify the correct answer."
    )
    if prompting == 'few_shot':
        prompt += prompt_few_shot(data, 3, 6)
        return prompt, word
    elif prompting == 'chain_of_thought':
        prompt += prompt_chain_of_thought()
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential':
        prompt += prompt_chain_of_thought_plus_sequential(3, word_difficulty, task_difficulty)
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential_rl':
        final_text, chosen_word = prompt_chain_of_thought_plus_sequential_rl(
            3, word_difficulty, task_difficulty, forbidden_list=words
        )
        return final_text, chosen_word
    elif prompting == 'chain_of_thought_plus_role_chain':
        prompt += prompt_chain_of_thought_plus_role_chain(3, word_difficulty, task_difficulty)
        return prompt, word
    else:
        return prompt, word


def generate_common_prefix_prompt(word_list, word_difficulty, task_difficulty, data, prompting):  # question_type = 4
    prompt = (
        f"Generate a 3-choice question for a student learning about morphemes. "
        f"The words given are {word_list}, with word difficulty {word_difficulty} and "
        f"task difficulty {task_difficulty}. The question should ask the student to identify the word "
        f"that does NOT share the same prefix as the others. Clearly specify the correct answer."
    )
    if prompting == 'few_shot':
        prompt += prompt_few_shot(data, 4, 6)
        return prompt, word_list
    elif prompting == 'chain_of_thought':
        prompt += prompt_chain_of_thought()
        return prompt, word_list
    elif prompting == 'chain_of_thought_plus_sequential':
        prompt += prompt_chain_of_thought_plus_sequential(4, word_difficulty, task_difficulty)
        return prompt, word_list
    elif prompting == 'chain_of_thought_plus_sequential_rl':
        final_text, chosen_word = prompt_chain_of_thought_plus_sequential_rl(
            4, word_difficulty, task_difficulty, forbidden_list=[], word_list=word_list
        )
        return final_text, chosen_word
    elif prompting == 'chain_of_thought_plus_role_chain':
        prompt += prompt_chain_of_thought_plus_role_chain(4, word_difficulty, task_difficulty)
        return prompt, word_list
    else:
        return prompt, word_list


def generate_common_suffix_prompt(word_list, word_difficulty, task_difficulty, data, prompting):  # question_type = 5
    prompt = (
        f"Generate a 3-choice question for a student learning about morphemes. "
        f"The words given are {word_list}, with word difficulty {word_difficulty} and "
        f"task difficulty {task_difficulty}. The question should ask the student to identify the word "
        f"that does NOT share the same suffix as the others. Clearly specify the correct answer."
    )
    if prompting == 'few_shot':
        prompt += prompt_few_shot(data, 5, 6)
        return prompt, word_list
    elif prompting == 'chain_of_thought':
        prompt += prompt_chain_of_thought()
        return prompt, word_list
    elif prompting == 'chain_of_thought_plus_sequential':
        prompt += prompt_chain_of_thought_plus_sequential(5, word_difficulty, task_difficulty)
        return prompt, word_list
    elif prompting == 'chain_of_thought_plus_sequential_rl':
        final_text, chosen_word = prompt_chain_of_thought_plus_sequential_rl(
            5, word_difficulty, task_difficulty, forbidden_list=[], word_list=word_list
        )
        return final_text, chosen_word
    elif prompting == 'chain_of_thought_plus_role_chain':
        prompt += prompt_chain_of_thought_plus_role_chain(5, word_difficulty, task_difficulty)
        return prompt, word_list
    else:
        return prompt, word_list


def generate_word_transformation_prompt(word_difficulty, task_difficulty, data, prompting, words):  # question_type = 6
    if words:
        word_exclusion = f" and it must NOT be any of these words (case insensitive): {', '.join(words)}."
    else:
        word_exclusion = ""

    gen_prompt = (
        f"Please generate an English word that has variations with different meanings{word_exclusion} "
        f"Its level of difficulty for grade 3-5 is {word_difficulty} out of 5.\n"
        f"Return your response in this exact format:\n"
        f"WORD: [your word]\n"
        f"EXPLANATION: [brief explanation why this word is appropriate]"
    )
    result = generate_gpt(gen_prompt)
    word_match = re.search(r"WORD:\s*(\w+)", result or "")
    word = word_match.group(1) if word_match else None

    prompt = (
        f"Generate a 3-choice question for a student learning about word transformations. "
        f"The word is '{word}', word difficulty {word_difficulty}, and task difficulty {task_difficulty}. "
        f"The question should ask the student to transform '{word}' to a new meaning, with two incorrect "
        f"choices and one correct answer. Clearly specify correct answer."
    )
    if prompting == 'few_shot':
        prompt += prompt_few_shot(data, 6, 6)
        return prompt, word
    elif prompting == 'chain_of_thought':
        prompt += prompt_chain_of_thought()
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential':
        prompt += prompt_chain_of_thought_plus_sequential(6, word_difficulty, task_difficulty)
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential_rl':
        final_text, chosen_word = prompt_chain_of_thought_plus_sequential_rl(
            6, word_difficulty, task_difficulty, forbidden_list=words
        )
        return final_text, chosen_word
    elif prompting == 'chain_of_thought_plus_role_chain':
        prompt += prompt_chain_of_thought_plus_role_chain(6, word_difficulty, task_difficulty)
        return prompt, word
    else:
        return prompt, word


def generate_word_meaning_prompt(word_difficulty, task_difficulty, data, prompting, words):  # question_type = 7
    if words:
        word_exclusion = f" and it must NOT be any of these words (case insensitive): {', '.join(words)}."
    else:
        word_exclusion = ""

    gen_prompt = (
        f"Please generate an English word that has a different meaning with a same prefix or suffix{word_exclusion} "
        f"Its level of difficulty for grade 3-5 is {word_difficulty} out of 5.\n"
        f"Return your response in this exact format:\n"
        f"WORD: [your word]\n"
        f"EXPLANATION: [brief explanation why this word is appropriate]"
    )
    result = generate_gpt(gen_prompt)
    word_match = re.search(r"WORD:\s*(\w+)", result or "")
    word = word_match.group(1) if word_match else None

    prompt = (
        f"Generate a 3-choice question for a student learning about affixed words. "
        f"The word is '{word}', with word difficulty {word_difficulty} and task difficulty {task_difficulty}. "
        f"The question should ask the student to select the correct meaning of '{word}' from three answer choices. "
        f"Clearly specify the correct answer."
    )
    if prompting == 'few_shot':
        prompt += prompt_few_shot(data, 7, 6)
        return prompt, word
    elif prompting == 'chain_of_thought':
        prompt += prompt_chain_of_thought()
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential':
        prompt += prompt_chain_of_thought_plus_sequential(7, word_difficulty, task_difficulty)
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential_rl':
        final_text, chosen_word = prompt_chain_of_thought_plus_sequential_rl(
            7, word_difficulty, task_difficulty, forbidden_list=words
        )
        return final_text, chosen_word
    elif prompting == 'chain_of_thought_plus_role_chain':
        prompt += prompt_chain_of_thought_plus_role_chain(7, word_difficulty, task_difficulty)
        return prompt, word
    else:
        return prompt, word


def generate_spelling_prompt(word_difficulty, task_difficulty, data, prompting, prompts):  # question_type = 8
    if prompts:
        prompt_restriction = (
            f" The question and the word should not be similar to any of the previously generated questions: "
            f"{', '.join(prompts)}."
        )
    else:
        prompt_restriction = ""

    prompt = (
        f"Generate a 3-choice question for a student learning about spelling based on morpheme meaning"
        f"{prompt_restriction} The question should include a word with a suffix."
        f"Provide two misspelled variations and one correct spelling. The question should have word difficulty "
        f"{word_difficulty} and task difficulty {task_difficulty}. Clearly specify the correct answer."
    )
    if prompting == 'few_shot':
        prompt += prompt_few_shot(data, 8, 6)
        return prompt, prompt
    elif prompting == 'chain_of_thought':
        prompt += prompt_chain_of_thought()
        return prompt, prompt
    elif prompting == 'chain_of_thought_plus_sequential':
        prompt += prompt_chain_of_thought_plus_sequential(8, word_difficulty, task_difficulty)
        return prompt, prompt
    elif prompting == 'chain_of_thought_plus_sequential_rl':
        final_text, chosen_word = prompt_chain_of_thought_plus_sequential_rl(
            8, word_difficulty, task_difficulty, forbidden_list=prompts
        )
        return final_text, chosen_word
    elif prompting == 'chain_of_thought_plus_role_chain':
        prompt += prompt_chain_of_thought_plus_role_chain(8, word_difficulty, task_difficulty)
        return prompt, prompt
    else:
        return prompt, prompt


def generate_affixed_word_breakdown_prompt(word_difficulty, task_difficulty, data, prompting, words):  # question_type = 9
    if words:
        word_exclusion = f" and it must NOT be any of these words (case insensitive): {', '.join(words)}."
    else:
        word_exclusion = ""

    gen_prompt = (
        f"Please generate an English word that has at least three parts and at most four parts{word_exclusion} "
        f"Its level of difficulty for grade 3-5 is {word_difficulty} out of 5.\n"
        f"Return your response in this exact format:\n"
        f"WORD: [your word]\n"
        f"EXPLANATION: [brief explanation why this word is appropriate]"
    )
    result = generate_gpt(gen_prompt)
    word_match = re.search(r"WORD:\s*(\w+)", result or "")
    word = word_match.group(1) if word_match else None

    prompt = (
        f"Generate a 3-choice question for a student learning to break affixed words into parts. "
        f"The word is '{word}', with word difficulty {word_difficulty} and task difficulty {task_difficulty}. "
        f"The question should ask the student to break '{word}' into its correct parts (prefix, root, suffix) "
        f"and provide two incorrect choices along with the correct answer. Please specify the correct answer."
    )
    if prompting == 'few_shot':
        prompt += prompt_few_shot(data, 9, 6)
        return prompt, word
    elif prompting == 'chain_of_thought':
        prompt += prompt_chain_of_thought()
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential':
        prompt += prompt_chain_of_thought_plus_sequential(9, word_difficulty, task_difficulty)
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential_rl':
        final_text, chosen_word = prompt_chain_of_thought_plus_sequential_rl(
            9, word_difficulty, task_difficulty, forbidden_list=words
        )
        return final_text, chosen_word
    elif prompting == 'chain_of_thought_plus_role_chain':
        prompt += prompt_chain_of_thought_plus_role_chain(9, word_difficulty, task_difficulty)
        return prompt, word
    else:
        return prompt, word


def generate_prefix_definition_prompt(word_difficulty, task_difficulty, data, prompting, words):  # question_type = 10
    if words:
        word_exclusion = f" and it must NOT be any of these words (case insensitive): {', '.join(words)}."
    else:
        word_exclusion = ""

    gen_prompt = (
        f"Please generate an English word that has a prefix{word_exclusion} "
        f"Its level of difficulty for grade 3-5 is {word_difficulty} out of 5.\n"
        f"Return your response in this exact format:\n"
        f"WORD: [your word]\n"
        f"EXPLANATION: [brief explanation why this word is appropriate]"
    )
    result = generate_gpt(gen_prompt)
    word_match = re.search(r"WORD:\s*(\w+)", result or "")
    word = word_match.group(1) if word_match else None

    prompt = (
        f"Generate a 3-choice question for a student learning about prefixes. "
        f"The word is '{word}', with word difficulty {word_difficulty} and task difficulty {task_difficulty}. "
        f"The question should ask the student to select the correct definition of the prefix in '{word}' from "
        f"three answer choices. Please specify the correct answer."
    )
    if prompting == 'few_shot':
        prompt += prompt_few_shot(data, 10, 6)
        return prompt, word
    elif prompting == 'chain_of_thought':
        prompt += prompt_chain_of_thought()
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential':
        prompt += prompt_chain_of_thought_plus_sequential(10, word_difficulty, task_difficulty)
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential_rl':
        final_text, chosen_word = prompt_chain_of_thought_plus_sequential_rl(
            10, word_difficulty, task_difficulty, forbidden_list=words
        )
        return final_text, chosen_word
    elif prompting == 'chain_of_thought_plus_role_chain':
        prompt += prompt_chain_of_thought_plus_role_chain(10, word_difficulty, task_difficulty)
        return prompt, word
    else:
        return prompt, word


def generate_root_word_definition_prompt(word_difficulty, task_difficulty, data, prompting, words):  # question_type = 11
    if words:
        word_exclusion = f" and it must NOT be any of these words (case insensitive): {', '.join(words)}."
    else:
        word_exclusion = ""

    gen_prompt = (
        f"Please generate an English word that has a prefix or suffix{word_exclusion} "
        f"Its level of difficulty for grade 3-5 is {word_difficulty} out of 5.\n"
        f"Return your response in this exact format:\n"
        f"WORD: [your word]\n"
        f"EXPLANATION: [brief explanation why this word is appropriate]"
    )
    result = generate_gpt(gen_prompt)
    word_match = re.search(r"WORD:\s*(\w+)", result or "")
    word = word_match.group(1) if word_match else None

    prompt = (
        f"Generate a 3-choice question for a student learning about root words in affixed words. "
        f"The word is '{word}', with word difficulty {word_difficulty} and task difficulty {task_difficulty}. "
        f"The question should ask the student to select the correct definition of the root word in '{word}' from "
        f"three answer choices. Please specify the correct answer."
    )
    if prompting == 'few_shot':
        prompt += prompt_few_shot(data, 11, 6)
        return prompt, word
    elif prompting == 'chain_of_thought':
        prompt += prompt_chain_of_thought()
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential':
        prompt += prompt_chain_of_thought_plus_sequential(11, word_difficulty, task_difficulty)
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential_rl':
        final_text, chosen_word = prompt_chain_of_thought_plus_sequential_rl(
            11, word_difficulty, task_difficulty, forbidden_list=words
        )
        return final_text, chosen_word
    elif prompting == 'chain_of_thought_plus_role_chain':
        prompt += prompt_chain_of_thought_plus_role_chain(11, word_difficulty, task_difficulty)
        return prompt, word
    else:
        return prompt, word


def generate_suffix_definition_prompt(word_difficulty, task_difficulty, data, prompting, words):  # question_type = 12
    if words:
        word_exclusion = f" and it must NOT be any of these words (case insensitive): {', '.join(words)}."
    else:
        word_exclusion = ""

    gen_prompt = (
        f"Please generate an English word that has a suffix{word_exclusion}"
        f"Its level of difficulty for grade 3-5 is {word_difficulty} out of 5.\n"
        f"Return your response in this exact format:\n"
        f"WORD: [your word]\n"
        f"EXPLANATION: [brief explanation why this word is appropriate]"
    )
    result = generate_gpt(gen_prompt)
    word_match = re.search(r"WORD:\s*(\w+)", result or "")
    word = word_match.group(1) if word_match else None

    prompt = (
        f"Generate a 3-choice question for a student learning about suffixes. "
        f"The word is '{word}', with word difficulty {word_difficulty} and task difficulty {task_difficulty}. "
        f"The question should ask the student to select the correct definition or function of the suffix in '{word}' "
        f"from three answer choices. Please specify the correct answer."
    )
    if prompting == 'few_shot':
        prompt += prompt_few_shot(data, 12, 6)
        return prompt, word
    elif prompting == 'chain_of_thought':
        prompt += prompt_chain_of_thought()
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential':
        prompt += prompt_chain_of_thought_plus_sequential(12, word_difficulty, task_difficulty)
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential_rl':
        final_text, chosen_word = prompt_chain_of_thought_plus_sequential_rl(
            12, word_difficulty, task_difficulty, forbidden_list=words
        )
        return final_text, chosen_word
    elif prompting == 'chain_of_thought_plus_role_chain':
        prompt += prompt_chain_of_thought_plus_role_chain(12, word_difficulty, task_difficulty)
        return prompt, word
    else:
        return prompt, word


def generate_morphologically_complex_word_definition_prompt(word_difficulty, task_difficulty, data, prompting, words):  # question_type = 13
    if words:
        word_exclusion = f" and it must NOT be any of these words (case insensitive): {', '.join(words)}."
    else:
        word_exclusion = ""
    gen_prompt = (
        f"Please generate an English word whose morpheme has a distinct meaning, can take a suffix or prefix,{word_exclusion}"
        f"Its level of difficulty for grade 3-5 is {word_difficulty} out of 5.\n"
        f"Return your response in this exact format:\n"
        f"WORD: [your word]\n"
        f"EXPLANATION: [brief explanation why this word is appropriate]"
    )
    result = generate_gpt(gen_prompt)
    word_match = re.search(r"WORD:\s*(\w+)", result or "")
    word = word_match.group(1) if word_match else None

    prompt = (
        f"Generate a 3-choice question for a student learning about morphologically complex words. "
        f"The word is '{word}'. With word difficulty {word_difficulty} and task difficulty {task_difficulty}, "
        f"the question should ask the student to select the correct definition of '{word}' based on its morphemes. "
        f"Please specify the correct answer."
    )
    if prompting == 'few_shot':
        prompt += prompt_few_shot(data, 13, 6)
        return prompt, word
    elif prompting == 'chain_of_thought':
        prompt += prompt_chain_of_thought()
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential':
        prompt += prompt_chain_of_thought_plus_sequential(13, word_difficulty, task_difficulty)
        return prompt, word
    elif prompting == 'chain_of_thought_plus_sequential_rl':
        final_text, chosen_word = prompt_chain_of_thought_plus_sequential_rl(
            13, word_difficulty, task_difficulty, forbidden_list=words
        )
        return final_text, chosen_word
    elif prompting == 'chain_of_thought_plus_role_chain':
        prompt += prompt_chain_of_thought_plus_role_chain(13, word_difficulty, task_difficulty)
        return prompt, word
    else:
        return prompt, word

###############################################################################
# 9. Dispatcher for Zero/Few/Chain-of-thought/Chain-of-thought-plus-sequential/
#    Chain-of-thought-plus-role-chain
###############################################################################

def load_lists(file):
    import json
    with open(file,'r') as f:
        list1=json.load(f)
    return list1

def prompt_generator(question_type, word_difficulty, task_difficulty, data, prompting, forbidden_list):
    list1=load_lists('/blue/babajani.a/babak.ahmadi/NLP_Dorr/Project/MA/JsonLists/list1.json')
    list2=load_lists('/blue/babajani.a/babak.ahmadi/NLP_Dorr/Project/MA/JsonLists/list2.json')

    if question_type == 1:
        return generate_prefix_prompt(word_difficulty, task_difficulty, data, prompting,forbidden_list)
    elif question_type == 2:
        return generate_suffix_prompt(word_difficulty, task_difficulty, data, prompting, forbidden_list)
    elif question_type == 3:
        return generate_root_word_prompt(word_difficulty, task_difficulty, data, prompting, forbidden_list)
    elif question_type == 4:
        allowed = [sublist for sublist in list1 if sublist not in forbidden_list]
        random_word_list = random.choice(allowed)
        return generate_common_prefix_prompt(random_word_list, word_difficulty, task_difficulty, data, prompting)
    elif question_type == 5:
        allowed = [sublist for sublist in list2 if sublist not in forbidden_list]
        random_word_list = random.choice(allowed)
        return generate_common_suffix_prompt(random_word_list, word_difficulty, task_difficulty, data, prompting)
    elif question_type == 6:
        return generate_word_transformation_prompt(word_difficulty, task_difficulty, data, prompting, forbidden_list)
    elif question_type == 7:
        return generate_word_meaning_prompt(word_difficulty, task_difficulty, data, prompting,forbidden_list)
    elif question_type == 8:
        return generate_spelling_prompt(word_difficulty, task_difficulty, data, prompting,forbidden_list)
    elif question_type == 9:
        return generate_affixed_word_breakdown_prompt(word_difficulty, task_difficulty, data, prompting,forbidden_list)
    elif question_type == 10:
        return generate_prefix_definition_prompt(word_difficulty, task_difficulty, data, prompting,forbidden_list)
    elif question_type == 11:
        return generate_root_word_definition_prompt(word_difficulty, task_difficulty, data, prompting,forbidden_list)
    elif question_type == 12:
        return generate_suffix_definition_prompt(word_difficulty, task_difficulty, data, prompting, forbidden_list)
    elif question_type == 13:
        return generate_morphologically_complex_word_definition_prompt(word_difficulty, task_difficulty, data, prompting,forbidden_list)
    else:
        # Catch-all for unspecified question_type
        return generate_definition_prompt(word_difficulty, task_difficulty, data, prompting, forbidden_list)

###############################################################################
# 10. A more comprehensive question parser
###############################################################################
import re

def parse_question_output(text):
    """
    A comprehensive parser for all the prompting strategies we discussed:
      - zero_shot
      - few_shot
      - chain_of_thought
      - chain_of_thought_plus_sequential
      - chain_of_thought_plus_sequential_rl
      - chain_of_thought_plus_role_chain

    This function carefully extracts:
      - teacher_reasoning, student_reasoning, psychometrician_reasoning
      - chain_of_thought
      - up to 3 steps (step_1, step_2, step_3)
      - question
      - choice_a, choice_b, choice_c
      - correct_answer

    Key Logic / Fallbacks:
      1) We match teacher/student/psychometrician with lines like:
         'Teacher:', '(1) Teacher Role:', 'Student:', 'Psychometrician:', 'Technometrician:', etc.
      2) Chain-of-thought can appear as '--- Chain of Thought ---', 'Chain-of-Thought:', etc.
      3) Steps appear as 'Step 1:', 'Step 1 (Pick Words):', etc., up to Step 3.
      4) Final question is searched in this order:
           - 'Final Question:', 'Updated Question:', 'Final MCQ:', 'My Final Question is:'
           - fallback: 'Question:'
           - if that fails, we look for a line ending with '?'
      5) Choices are labeled 'A)', 'A.', 'A:', 'B)', 'C)', etc. We use a multiline regex to capture
         until we see the next choice label, 'Correct Answer:', or the end of the text (\\Z).
      6) Correct Answer is first looked for with lines like 'Correct Answer:', 'Answer:', or
         'The correct answer is:'. If not found, we see if one of the choices ends with '(Correct answer)'
         (case-insensitive). If so, we remove that parenthetical from the choice and set that as correct_answer.

    It returns a dictionary with these keys:
      {
        'question': str or None,
        'choice_a': str or None,
        'choice_b': str or None,
        'choice_c': str or None,
        'correct_answer': str or None,
        'chain_of_thought': str or None,
        'teacher_reasoning': str or None,
        'student_reasoning': str or None,
        'psychometrician_reasoning': str or None,
        'step_1': str or None,
        'step_2': str or None,
        'step_3': str or None
      }
    """

    # 0) If there's no text or it's empty, return a blank parse.
    if not text or not text.strip():
        return {
            'question': None,
            'choice_a': None,
            'choice_b': None,
            'choice_c': None,
            'correct_answer': None,
            'chain_of_thought': None,
            'teacher_reasoning': None,
            'student_reasoning': None,
            'psychometrician_reasoning': None,
            'step_1': None,
            'step_2': None,
            'step_3': None
        }

    # Normalize line endings to "\n"
    text = text.replace('\r\n', '\n')

    # Our parsed results dictionary
    parsed = {
        'question': None,
        'choice_a': None,
        'choice_b': None,
        'choice_c': None,
        'correct_answer': None,
        'chain_of_thought': None,
        'teacher_reasoning': None,
        'student_reasoning': None,
        'psychometrician_reasoning': None,
        'step_1': None,
        'step_2': None,
        'step_3': None
    }

    ################################################################
    # 1) Extract Teacher / Student / Psychometrician reasonings
    ################################################################
    teacher_match = re.search(
        r"(?i)(?:\(?\d\)?\s*Teacher\s*Role\s*:|Teacher\s*:)(.*?)(?=\n\s*(?:\(?\d\)?\s*Student\s*Role\s*:|Student\s*:|\(?\d\)?\s*Psychometrician\s*Role\s*:|Psychometrician\s*:|Technometrician\s*:|\(?\d\)?\s*Technometrician\s*Role\s*:|Final\s*Question\s*:|Updated\s*Question\s*:|Question\s*:|$))",
        text, re.DOTALL
    )
    if teacher_match:
        parsed['teacher_reasoning'] = teacher_match.group(1).strip()

    student_match = re.search(
        r"(?i)(?:\(?\d\)?\s*Student\s*Role\s*:|Student\s*:)(.*?)(?=\n\s*(?:\(?\d\)?\s*Teacher\s*Role\s*:|Teacher\s*:|\(?\d\)?\s*Psychometrician\s*Role\s*:|Psychometrician\s*:|Technometrician\s*:|\(?\d\)?\s*Technometrician\s*Role\s*:|Final\s*Question\s*:|Updated\s*Question\s*:|Question\s*:|$))",
        text, re.DOTALL
    )
    if student_match:
        parsed['student_reasoning'] = student_match.group(1).strip()

    psych_match = re.search(
        r"(?i)(?:\(?\d\)?\s*Psychometrician\s*Role\s*:|Psychometrician\s*:|\(?\d\)?\s*Technometrician\s*Role\s*:|Technometrician\s*:)(.*?)(?=\n\s*(?:\(?\d\)?\s*Teacher\s*Role\s*:|Teacher\s*:|\(?\d\)?\s*Student\s*Role\s*:|Student\s*:|Final\s*Question\s*:|Updated\s*Question\s*:|Question\s*:|$))",
        text, re.DOTALL
    )
    if psych_match:
        parsed['psychometrician_reasoning'] = psych_match.group(1).strip()

    ################################################################
    # 2) Extract chain-of-thought
    ################################################################
    # Could appear as '--- Chain of Thought ---' or 'Chain-of-Thought:'
    cot_match = re.search(
        r"(?i)(?:---\s*Chain[\s\-_]*of[\s\-_]*Thought\s*---|Chain[\s\-_]*of[\s\-_]*Thought\s*:)(.*?)(?=\n---|\nQuestion|\nStep|\Z)",
        text, re.DOTALL
    )
    if cot_match:
        parsed['chain_of_thought'] = cot_match.group(1).strip()

    ################################################################
    # 3) Extract up to 3 Steps: Step 1, Step 2, Step 3
    ################################################################
    # Usually from chain_of_thought_plus_sequential
    for n in range(1, 4):
        step_regex = (
            rf"(?is)(?:Step\s*{n}\s*(?:\(.*?\))?\s*[:\.]\s*)(.*?)(?="
            rf"^\s*Step\s*{n+1}\s*|^\s*Question\s*:|^\s*Final\s*Question\s*:|^\s*Updated\s*Question\s*:|\Z)"
        )
        match = re.search(step_regex, text, re.MULTILINE)
        if match:
            parsed[f'step_{n}'] = match.group(1).strip()
            
    # 3.1) Extract Step 1, Step 2, Step 3 (if present)
    #    For example: "Step 1 (Pick Words):\n....\nStep 2 (Draft Question): ..."
    #    We'll use a simple pattern that looks for lines starting with "Step X" up to the next "Step" or the end.
    step_regex = re.compile(
        r"(?ims)(Step\s*1\s*\(?.*?\)?:\s*)(.*?)(?=\n\s*Step\s*2\s*\(?|$)"
    )
    match = step_regex.search(text)
    if match:
        parsed['step_1'] = match.group(2).strip()

    step_regex = re.compile(
        r"(?ims)(Step\s*2\s*\(?.*?\)?:\s*)(.*?)(?=\n\s*Step\s*3\s*\(?|$)"
    )
    match = step_regex.search(text)
    if match:
        parsed['step_2'] = match.group(2).strip()

    step_regex = re.compile(
        r"(?ims)(Step\s*3\s*\(?.*?\)?:\s*)(.*)"
    )
    match = step_regex.search(text)
    if match:
        parsed['step_3'] = match.group(2).strip()

    ################################################################
    # 4) Extract the final question from known headings
    ################################################################
    # "Final Question:", "Updated Question:", "Final MCQ:",
    # "My Final Question is:", fallback "Question:"
    question_pattern = re.compile(
        r"(?is)(?:"
        r"(Final\s+Question\s*:\s*)"
        r"|(Updated\s+Question\s*:\s*)"
        r"|(Final\s*MCQ\s*:\s*)"
        r"|(My\s+Final\s+Question\s+is\s*:\s*)"
        r"|(Question\s*:\s*)"
        r")(.+)",
        re.IGNORECASE
    )
    question_match = question_pattern.search(text)
    if question_match:
        remainder = question_match.group(len(question_match.groups()))
        if remainder:
            splitted = re.split(
                r"\n\s*(?:A\)|A\.|A:|Correct\s*Answer\s*:)",
                remainder,
                maxsplit=1,
                flags=re.IGNORECASE
            )
            parsed['question'] = splitted[0].strip() if splitted else remainder.strip()

    ################################################################
    # 5) Fallback: "Question:" if we didn't parse it above
    ################################################################
    if not parsed['question']:
        q_fallback = re.search(r"(?i)Question\s*:\s*(.*)", text, re.DOTALL)
        if q_fallback:
            remainder = q_fallback.group(1)
            splitted = re.split(
                r"\n\s*(?:A\)|A\.|A:|Correct\s*Answer\s*:)",
                remainder,
                maxsplit=1,
                flags=re.IGNORECASE
            )
            parsed['question'] = splitted[0].strip() if splitted else remainder.strip()

    ################################################################
    # 6) If STILL no question => find the first line ending with '?'
    ################################################################
    if not parsed['question']:
        question_line_match = re.search(r"^(.*\?)\s*$", text, re.MULTILINE)
        if question_line_match:
            parsed['question'] = question_line_match.group(1).strip()

    ################################################################
    # 7) Extract choices A), B), C)
    ################################################################
    # We'll allow the pattern to continue until the next choice, a "Correct Answer:", 
    # a blank line, or the end of text (\Z). That way we capture lines like
    #   C) Un- (Correct answer)
    # even if there's no trailing newline.
    def capture_choice(label, full_text):
        pattern = (
            rf"(?ims)^[ \t]*{label}\s*[\)\.:]\s*(.*?)(?="
            rf"^[ \t]*[{chr(ord(label)+1)}]\s*[\)\.:]|"
            rf"^[ \t]*Correct\s*Answer\s*:|"
            rf"^$|"
            rf"\Z)"
        )
        m = re.search(pattern, full_text, re.MULTILINE)
        if m:
            return m.group(1).strip()
        return None

    parsed['choice_a'] = capture_choice('A', text)
    parsed['choice_b'] = capture_choice('B', text)
    parsed['choice_c'] = capture_choice('C', text)

    ################################################################
    # 8) Check for "Correct Answer:" or "Answer:" or 
    #    "The correct answer is:" lines
    ################################################################
    ans_match = re.search(
        r"(?i)(?:Correct\s*Answer\s*:\s*|Answer\s*:\s*|The\s*correct\s*answer\s*is\s*)(.*)",
        text
    )
    if ans_match:
        ans_raw = ans_match.group(1).strip()
        # If the answer text starts with something like "C) " or "C. " or "C:", strip that off
        ans_no_label = re.sub(r'^[ABCabc]\s*[\)\.:]\s*', '', ans_raw).strip()
        parsed['correct_answer'] = ans_no_label

    ################################################################
    # 9) If STILL no correct_answer => check if any choice ends with 
    #    parentheses containing "correct", e.g. (Correct answer)
    ################################################################
    if not parsed['correct_answer']:
        for label in ['a', 'b', 'c']:
            choice_key = f'choice_{label}'
            val = parsed[choice_key]
            if not val:
                continue
            paren_match = re.search(r'\(\s*(.*?)\s*\)\s*$', val)
            if paren_match:
                # e.g. "Un- (Correct answer)"
                paren_text = paren_match.group(1)
                if re.search(r'correct', paren_text, re.IGNORECASE):
                    # remove that parenthetical from the choice
                    val_no_paren = re.sub(r'\(\s*.*?\s*\)\s*$', '', val).strip()
                    parsed[choice_key] = val_no_paren
                    parsed['correct_answer'] = val_no_paren
                    break

    return parsed


    
if __name__ == "__main__":
    test_api_access()
    #model, tokenizer= train_gemma()
    #model_path = "/blue/babajani.a/babak.ahmadi/NLP_Dorr/Project/MA/last_gemma_morphology_20250404_014910/final_model"
    # common_words = [
    # "the", "be", "to", "of", "and", "in", "that", "have", "I", 
    # "it", "for", "not", "on", "with", "he", "as", "you", "do", "at",
    # "this", "but", "his", "by", "from", "they", "we", "say", "her", "she",
    # "or", "an", "will", "my", "one", "all", "would", "there", "their", "what",
    # "so", "up", "out", "if", "about", "who", "get", "which", "go", "me",
    # "when", "make", "can", "like", "time", "no", "just", "him", "know", "take",
    # "people", "into", "year", "your", "good", "some", "could", "them", "see", "other",
    # "than", "then", "now", "look", "only", "come", "its", "over", "think", "also",
    # "back", "after", "use", "two", "how", "our", "work", "first", "well", "way",
    # "even", "new", "want", "because", "any", "these", "give", "day", "most", "us","none" ,"an","like","with"]
    
    
    data_file = 'MC_data_MA2.csv'
    
    strategies = [
        'chain_of_thought_plus_sequential_rl',
        'chain_of_thought_plus_role_chain',
        'chain_of_thought',
        'chain_of_thought_plus_sequential',
        'few_shot',
        'zero_shot'
    ]

    data = pd.read_csv(data_file, encoding='utf-8')
    NUM_QUESTIONS = 3
    word_difficulties = [1,2,3,4,5] #data["Word_Difficulty"].unique()
    task_difficulties = ['E', 'H', 'M']
    # Question_Type_array = np.array(data["Question_Type"].unique())
    # questio_id = [int(float(x)) for x in Question_Type_array]
    questio_id = list(range(1,14))
    for strategy in strategies:
        questions_data = []
        # for question_type in questio_id:
        #     if question_type not in [4,5]:
        #         prev_prompts = {q_type: [common_words] for q_type in questio_id}
        #     else:
        prev_prompts = {q_type: [] for q_type in questio_id}

        for word_difficulty in word_difficulties:
            for task_difficulty in task_difficulties:
                for question_type in questio_id:
                    for i in range(NUM_QUESTIONS):
                        print(f"\n=== Question #{i+1} === Question Type #{question_type} === {strategy} ===")
                        prompt_or_final_text, new_word = prompt_generator(
                            question_type,
                            word_difficulty,
                            task_difficulty,
                            data,
                            strategy,
                            prev_prompts[question_type]
                        )
                        # 2) 
                        if strategy == "chain_of_thought_plus_sequential_rl":
                            # The function already did multi-step GPT calls. 
                            # So use the combined text returned from prompt_generator:
                            generated_text = prompt_or_final_text
                            parse_text = generated_text
                        else:
                            # single-step strategy
                            generated_text = generate_gpt(prompt_or_final_text)
                            parse_text = generated_text
                        #parsed = parse_question_output(parse_text or "")
                        # 3) Parse the relevant text
                        if generated_text:
                            parsed = parse_question_output(generated_text)
                            if parsed:
                                parsed['generated_text'] = generated_text
                                parsed['question_type'] = question_type
                                parsed['word_difficulty'] = word_difficulty
                                parsed['task_difficulty'] = task_difficulty
                                parsed['prompting_strategy'] = strategy
                                questions_data.append(parsed)

                        if new_word:
                            prev_prompts[question_type].append(new_word)

                        if generated_text:
                            print("\nGenerated Text from GPT-3.5 Model:")
                            print(generated_text)
                        else:
                            print("No text returned by the model.")

        # Save after finishing one strategy
        df = pd.DataFrame(questions_data)
        filename = f'Final_generated_questions_GPT_{strategy}.csv'
        df.to_csv(filename, index=False)
        print(f"\nSaved questions for strategy '{strategy}' to {filename}")
# Out:
# === Question #1 === Question Type #1 === chain_of_thought_plus_sequential_rl ===
# ==> Step 1 result: 1. Unhappy
# - Choice 1: Disagree
# - Choice 2: Misunderstand
# - Correct Answer: Unhappy
#
# Chain-of-thought:
# "Unhappy" is a suitable word for this question as it contains the prefix "un-". The incorrect choices "disagree" and "misunderstand" both contain different prefixes, which can help test the student's understanding of identifying the correct prefix in a word.
#
# 2. Preheat
# - Choice 1: Overheat
# - Choice 2: Reheat
# - Correct Answer: Preheat
#
# Chain-of-thought:
# "Preheat" is a good choice as it clearly contains the prefix "pre-". The incorrect choices "overheat" and "reheat" also contain prefixes, but different ones. This can help challenge the student to identify the correct prefix in the given word.
#
# 3. Disappear
# - Choice 1: Appear
# - Choice 2: Reappear
# - Correct Answer: Disappear
#
# Chain-of-thought:
# "Disappear" is a suitable word as it contains the prefix "dis-". The incorrect choices "appear" and "reappear" both contain different prefixes, which can test the student's ability to identify the correct prefix in a word.
#
# Final Word: Preheat
# Reasoning: I choose "Preheat" as the final word because it contains the prefix "pre-", which is a common prefix that students at this level should be familiar with. The incorrect choices also contain different prefixes, making it a good challenge for the student to identify the correct prefix in the word.
#
# ==> Step 2 result: Question: In the word "Preheat," which part is the prefix?
# A) Pre-
# B) Heat
# C) Re-
#
# Correct Answer: A) Pre-
#
# Chain of Thought:
# 1. Identify the chosen word: Preheat
# 2. Recognize the prefix in the word: Pre-
# 3. Provide two incorrect choices that are other parts of the word: Heat and Re-
#
# ==> Step 3 result: Updated Question: In the word "Preheat," which part is the prefix?
# A) Pre-
# B) Heat
# C) Re-
# Correct Answer: A) Pre-
#
# Reasoning for Distractor B) Heat: This choice might trick the student because "heat" is a part of the word "Preheat," but it is not the prefix.
#
# Reasoning for Distractor C) Re-: This choice might trick the student because "re-" is a common prefix in English words, but in the word "Preheat," the prefix is "pre-."
#
# By shuffling the answer choices, the final question now provides a clear and challenging task for the student.
#
# ====== HERE IS THE FORBIDDEN_LIST: []
#
#
# Generated Text from GPT-3.5 Model:
# Updated Question: In the word "Preheat," which part is the prefix?
# A) Pre-
# B) Heat
# C) Re-
# Correct Answer: A) Pre-
#
# Reasoning for Distractor B) Heat: This choice might trick the student because "heat" is a part of the word "Preheat," but it is not the prefix.
#
# Reasoning for Distractor C) Re-: This choice might trick the student because "re-" is a common prefix in English words, but in the word "Preheat," the prefix is "pre-."
#
# By shuffling the answer choices, the final question now provides a clear and challenging task for the student.
#
# === Question #2 === Question Type #1 === chain_of_thought_plus_sequential_rl ===
# ==> Step 1 result: 1. Unhappy - The word "unhappy" contains the prefix "un-," which means "not." This word is suitable because it clearly demonstrates the concept of a prefix attached to a base word.
#
# 2. Disagree - The word "disagree" contains the prefix "dis-," which means "apart" or "not." This word is appropriate as it also illustrates the concept of a prefix altering the meaning of a base word.
#
# 3. Preheat - The word "preheat" contains the prefix "pre-," which means "before." This word is a good choice as it shows how a prefix can indicate the timing or sequence of an action.
#
# Final Choice: Unhappy - I choose "unhappy" as the final word because it is a common word that clearly displays the prefix "un-." This word is simple and straightforward, making it suitable for students at the Grade 3-5 level to identify the prefix easily.
#
# ==> Step 2 result: Step 2 (Draft Question):
#     We have chosen the word: unhappy.
#
#     Now draft a 3-choice question based on the following instruction: We want to generate a 3-choice question for a student learning about prefixes. The word difficulty must be 1 and task difficulty must be E. Be informed that ultimately, the question should ask the student to identify the prefix in a chosen word and provide two incorrect choices along with the correct answer. Provide a chain-of-thought explaining how you formed the question, and provide the correct answer.
#
#     Do NOT finalize the answer choices yet. Give the question text
#     and placeholders for A/B/C. For instance:
#     "Question: ... A) ... B) ... C) ..."
#
# Question: In the word "unhappy," what is the prefix? A) un- B) hap- C) -py
#
# ==> Step 3 result: Question: In the word "unhappy," what is the prefix? A) un- B) hap- C) -py
#
# Update the TWO distractors:
# - Distractor B: "hap-" is not the prefix in the word "unhappy," as the prefix is actually "un-." This distractor might trick the student by focusing on the root word rather than the prefix.
# - Distractor C: "-py" is not the prefix in the word "unhappy," as the prefix is actually "un-." This distractor might trick the student by presenting a suffix as a possible prefix.
#
# Correct Answer: A) un-
#
# Chain-of-thought:
# - The prefix in the word "unhappy" is "un-," which is added to the root word "happy" to change its meaning.
# - Distractor B ("hap-") focuses on part of the root word, while distractor C ("-py") presents a suffix, both of which are not correct prefixes.
#
# ====== HERE IS THE FORBIDDEN_LIST: ['Preheat']
#
#
# Generated Text from GPT-3.5 Model:
# Question: In the word "unhappy," what is the prefix? A) un- B) hap- C) -py
#
# Update the TWO distractors:
# - Distractor B: "hap-" is not the prefix in the word "unhappy," as the prefix is actually "un-." This distractor might trick the student by focusing on the root word rather than the prefix.
# - Distractor C: "-py" is not the prefix in the word "unhappy," as the prefix is actually "un-." This distractor might trick the student by presenting a suffix as a possible prefix.
#
# Correct Answer: A) un-
#
# Chain-of-thought:
# - The prefix in the word "unhappy" is "un-," which is added to the root word "happy" to change its meaning.
# - Distractor B ("hap-") focuses on part of the root word, while distractor C ("-py") presents a suffix, both of which are not correct prefixes.
#
# === Question #3 === Question Type #1 === chain_of_thought_plus_sequential_rl ===
# ==> Step 1 result: 1. Unhappy - The word "unhappy" contains the prefix "un-" meaning not. This word is suitable as it is a common word that students in grades 3-5 are likely familiar with and can easily identify the prefix in.
#
# 2. Disappear - The word "disappear" contains the prefix "dis-" meaning not or opposite of. This word is appropriate as it introduces a different prefix for students to identify and challenges them to think about prefixes in various words.
#
# 3. Preheat - The word "preheat" contains the prefix "pre-" meaning before. This word is a good choice as it introduces a different prefix that students may not be as familiar with, expanding their knowledge of prefixes.
#
# Final word: Unhappy
# Reasoning: I choose "unhappy" as the final word because it is a common word that students are likely familiar with, making it easier for them to identify the prefix "un-" in it. Additionally, the prefix "un-" is a commonly taught prefix in elementary school, making it a suitable choice for this question.
#
# ==> Step 2 result: Step 3 (Draft Question):
#
# Question: In the word "Joyful," what is the prefix?
# A) dis-
# B) un-
# C) joy-
#
# Correct Answer: C) joy-
#
# Chain-of-Thought:
# 1. Start by identifying the word "Joyful" and determining that the prefix needs to be identified.
# 2. Understand that the prefix is what comes before the root word, which in this case is "joy."
# 3. Provide two incorrect choices, "dis-" and "un-," which are common prefixes but do not apply to the word "joyful."
# 4. Offer "joy-" as the correct answer because it is the actual prefix in the word "Joyful."
#
# ==> Step 3 result: Step 3 (Draft Question):
#
# Question: In the word "Joyful," what is the prefix?
# A) dis- (This prefix is commonly used to indicate negation or reversal, which might trick the student into thinking it applies to "Joyful.")
# B) un- (Similarly, this prefix is also used for negation, which could lead the student to mistakenly choose it for "Joyful.")
# C) joy- (This is the correct answer as "joy-" is the actual prefix in the word "Joyful.")
#
# Correct Answer: C) joy-
#
# Final Question:
# Question: In the word "Joyful," what is the prefix?
# A) dis-
# B) un-
# C) joy-
# Correct Answer: C) joy-
#
# ====== HERE IS THE FORBIDDEN_LIST: ['Preheat', 'unhappy']
#
#
# Generated Text from GPT-3.5 Model:
# Step 3 (Draft Question):
#
# Question: In the word "Joyful," what is the prefix?
# A) dis- (This prefix is commonly used to indicate negation or reversal, which might trick the student into thinking it applies to "Joyful.")
# B) un- (Similarly, this prefix is also used for negation, which could lead the student to mistakenly choose it for "Joyful.")
# C) joy- (This is the correct answer as "joy-" is the actual prefix in the word "Joyful.")
#
# Correct Answer: C) joy-
#
# Final Question:
# Question: In the word "Joyful," what is the prefix?
# A) dis-
# B) un-
# C) joy-
# Correct Answer: C) joy-
#
# === Question #1 === Question Type #2 === chain_of_thought_plus_sequential_rl ===
# ==> Step 1 result: 1. Happily - This word ends in "-ly", which is a common suffix that changes an adjective into an adverb. This word is appropriate because it clearly demonstrates the concept of suffixes.
#
# 2. Jumping - This word ends in "-ing", which is a suffix that is commonly added to verbs to indicate continuous or ongoing action. This word is suitable because it showcases a different type of suffix compared to the first choice.
#
# 3. Faster - This word ends in "-er", which is a suffix used to compare two things or individuals. This word is relevant because it highlights another common suffix pattern.
#
# Final word: Jumping
# Reasoning: I choose "Jumping" as the final word because it ends in the suffix "-ing", which is a common and easily recognizable suffix that is added to verbs to indicate ongoing action. This word will provide a good example for students to identify and understand the concept of suffixes.
#
# ==> Step 2 result: Step 3 (Draft Question):
# Question: What is the suffix in the word "Jumping"?
# A) -ing
# B) -ump
# C) -umping
#
# Chain-of-thought:
# 1. Identify the word: Jumping
# 2. Recognize that the suffix is the ending part of the word that modifies its meaning
# 3. Break down the word to identify the suffix "-ing"
# 4. Generate two incorrect choices by combining parts of the word with the suffix ("-ump" and "-umping")
# 5. Ensure that the correct answer reflects the actual suffix in the word "Jumping"
#
# Correct Answer: A) -ing
#
# ==> Step 3 result: Updated Question:
# Question: What is the suffix in the word "Jumping"?
# A) -ing
# B) -ump
# C) -umping
# Correct Answer: A) -ing
#
# Reasoning for Distractors:
# B) -ump: This distractor might trick the student because it is a part of the word "Jumping" but not the suffix. It could mislead the student into thinking that "-ump" is the suffix when it is actually "-ing".
# C) -umping: This distractor combines the base word "Jump" with an incorrect suffix "-umping". It might confuse the student by making them think that "-umping" is the correct suffix when it is actually "-ing".
#
# Final Question:
# Question: What is the suffix in the word "Jumping"?
# A) -ing
# B) -ump
# C) -umping
# Correct Answer: A) -ing
#
# ====== HERE IS THE FORBIDDEN_LIST: []
#
#
# Generated Text from GPT-3.5 Model:
# Updated Question:
# Question: What is the suffix in the word "Jumping"?
# A) -ing
# B) -ump
# C) -umping
# Correct Answer: A) -ing
#
# Reasoning for Distractors:
# B) -ump: This distractor might trick the student because it is a part of the word "Jumping" but not the suffix. It could mislead the student into thinking that "-ump" is the suffix when it is actually "-ing".
# C) -umping: This distractor combines the base word "Jump" with an incorrect suffix "-umping". It might confuse the student by making them think that "-umping" is the correct suffix when it is actually "-ing".
#
# Final Question:
# Question: What is the suffix in the word "Jumping"?
# A) -ing
# B) -ump
# C) -umping
# Correct Answer: A) -ing
#
# === Question #2 === Question Type #2 === chain_of_thought_plus_sequential_rl ===
# ==> Step 1 result: 1. Jumping
#    - Choice 1: Jumper (incorrect - this is a noun form of the word)
#    - Choice 2: Jumped (incorrect - this is the past tense form of the word)
#    - Choice 3: ing (correct - this is the suffix added to create the present participle form)
#
# 2. Happily
#    - Choice 1: Happy (incorrect - this is the root word)
#    - Choice 2: Happen (incorrect - this is a different word)
#    - Choice 3: ly (correct - this is the suffix added to create the adverb form)
#
# 3. Running
#    - Choice 1: Run (incorrect - this is the root word)
#    - Choice 2: Runner (incorrect - this is a noun form of the word)
#    - Choice 3: ing (correct - this is the suffix added to create the present participle form)
#
# Final Word: Running
# Reasoning: "Running" is the final word chosen because it clearly demonstrates the use of a suffix (-ing) to create the present participle form of the verb. The incorrect choices are also logically related to the word, making it a suitable option for the question.
#
# ==> Step 2 result: Question: What is the suffix in the word "Running"? A) -ing B) -run C) -ning
#
# Correct Answer: A) -ing
#
# Chain-of-thought:
# 1. Identify the chosen word: Running
# 2. Recognize that the suffix in the word is "-ing"
# 3. Formulate incorrect choices that resemble suffixes but do not actually match the suffix in the word
# 4. Present the question with three answer choices for the student to select from
#
# ==> Step 3 result: Updated Choices with Reasoning:
# A) -run: This choice might trick the student because it resembles the word "Running" and could be mistakenly chosen as the suffix, even though the correct suffix is "-ing".
# B) -ning: This choice might trick the student because it also resembles the word "Running" and could be mistakenly chosen as the suffix, even though the correct suffix is "-ing".
#
# Final Question:
# Question: What is the suffix in the word "Running"?
# A) -run
# B) -ning
# C) -ing
# Correct Answer: C) -ing
#
# ====== HERE IS THE FORBIDDEN_LIST: ['Jumping']
#
#
# Generated Text from GPT-3.5 Model:
# Updated Choices with Reasoning:
# A) -run: This choice might trick the student because it resembles the word "Running" and could be mistakenly chosen as the suffix, even though the correct suffix is "-ing".
# B) -ning: This choice might trick the student because it also resembles the word "Running" and could be mistakenly chosen as the suffix, even though the correct suffix is "-ing".
#
# Final Question:
# Question: What is the suffix in the word "Running"?
# A) -run
# B) -ning
# C) -ing
# Correct Answer: C) -ing
#
# === Question #3 === Question Type #2 === chain_of_thought_plus_sequential_rl ===
# ==> Step 1 result: 1. Jumping - This word ends in "-ing," which is a common suffix used to form present participle verbs. This word is appropriate as it clearly demonstrates the concept of a suffix.
#
# 2. Happily - This word ends in "-ly," which is a common suffix used to form adverbs. This word is suitable as it showcases a different type of suffix compared to the first choice.
#
# 3. Teacher - This word does not have a visible suffix at the end. This word is included to provide a contrast to the other choices and to ensure that the student can identify the presence of a suffix in the correct answer.
#
# Final Word: Happily
# Reasoning: I choose "Happily" as the final word because it clearly demonstrates the concept of a suffix that forms adverbs. This choice provides a clear example for the student to identify the suffix "-ly" in the word.
#
# ==> Step 2 result: Question: Which suffix is found in the word "Happily"?
#     A) -ly
#     B) -ful
#     C) -ness
#
# Correct Answer: A) -ly
#
# Chain-of-Thought:
# 1. First, identify the word "Happily" and determine that the suffix in this word is "-ly."
# 2. Provide two incorrect choices that are commonly mistaken as suffixes in other words (-ful and -ness) to challenge the student's understanding of suffixes.
# 3. By presenting three choices with one correct answer, the student can demonstrate their knowledge of identifying suffixes in words.
#
# ==> Step 3 result: Updated Choices with Reasoning:
# B) -ful: This suffix is commonly found in words like "beautiful" or "playful," which might lead the student to associate it with "Happily" as well.
# C) -ness: While this suffix is found in words like "happiness" or "kindness," the student might mistakenly think it is the suffix in "Happily" due to the similarity in sound.
#
# Final Question:
# Which suffix is found in the word "Happily"?
# A) -ly
# B) -ful
# C) -ness
#
# Correct Answer: A) -ly
#
# ====== HERE IS THE FORBIDDEN_LIST: ['Jumping', 'Running']
#
#
# Generated Text from GPT-3.5 Model:
# Updated Choices with Reasoning:
# B) -ful: This suffix is commonly found in words like "beautiful" or "playful," which might lead the student to associate it with "Happily" as well.
# C) -ness: While this suffix is found in words like "happiness" or "kindness," the student might mistakenly think it is the suffix in "Happily" due to the similarity in sound.
#
# Final Question:
# Which suffix is found in the word "Happily"?
# A) -ly
# B) -ful
# C) -ness
#
# Correct Answer: A) -ly
#
# === Question #1 === Question Type #3 === chain_of_thought_plus_sequential_rl ===
# ==> Step 1 result: Word 1: Unhappy
# - Root Word: "happy"
# - Incorrect Choice 1: "un"
# - Incorrect Choice 2: "happ"
# - Reasoning: "Unhappy" is a Grade 3-5 level word that contains a clear root word "happy" which can be easily identified by students. The incorrect choices "un" and "happ" are common prefixes and suffixes that might confuse students.
#
# Word 2: Teacher
# - Root Word: "teach"
# - Incorrect Choice 1: "er"
# - Incorrect Choice 2: "tea"
# - Reasoning: "Teacher" is a familiar word for students in Grade 3-5 and the root word "teach" is easily identifiable. The incorrect choices "er" and "tea" are common suffixes and a related word, respectively, that might distract students.
#
# Word 3: Beautiful
# - Root Word: "beauty"
# - Incorrect Choice 1: "ful"
# - Incorrect Choice 2: "beaut"
# - Reasoning: "Beautiful" is a common word that students encounter in Grade 3-5 with a clear root word "beauty". The incorrect choices "ful" and "beaut" are a common suffix and the incomplete root word, respectively, that could be misleading.
#
# Final Word: Unhappy
# Reasoning: I choose "Unhappy" as the final word because it is a Grade 3-5 level word that contains a clear root word "happy" which can be easily identified by students. The incorrect choices "un" and "happ" are common prefixes and suffixes that might confuse students, making it a suitable word for a 3-choice question about root words.
#
# ==> Step 2 result: Step 2 (Draft Question):
# Question: What is the root word in the word "Unhappy"?
# A) Happy
# B) Un
# C) Unh
# Correct Answer: A) Happy
#
# Chain-of-Thought:
# 1. Identify the word "Unhappy" and determine the root word within it, which is "Happy."
# 2. Create two incorrect choices that may seem plausible to a student learning about root words, such as "Un" (part of the original word) and "Unh" (a combination of the prefix and root word).
# 3. Present the question with the three answer choices for the student to select the correct root word.
#
# ==> Step 3 result: Updated Question:
# Question: What is the root word in the word "Unhappy"?
# A) Happy
# B) Un
# C) Unh
# Correct Answer: A) Happy
#
# Reasoning:
# Choice B (Un): This distractor might trick the student because "Un" is the prefix attached to the root word "happy" in the original word "Unhappy." Students might mistakenly identify the prefix as the root word.
# Choice C (Unh): This distractor might confuse the student as it combines the prefix "Un" with the first letter of the root word "happy." This could lead the student to believe that "Unh" is the root word.
#
# By presenting these distractors alongside the correct answer "Happy," the student must carefully analyze the structure of the word to determine the correct root word.
#
# ====== HERE IS THE FORBIDDEN_LIST: []
#
#
# Generated Text from GPT-3.5 Model:
# Updated Question:
# Question: What is the root word in the word "Unhappy"?
# A) Happy
# B) Un
# C) Unh
# Correct Answer: A) Happy
#
# Reasoning:
# Choice B (Un): This distractor might trick the student because "Un" is the prefix attached to the root word "happy" in the original word "Unhappy." Students might mistakenly identify the prefix as the root word.
# Choice C (Unh): This distractor might confuse the student as it combines the prefix "Un" with the first letter of the root word "happy." This could lead the student to believe that "Unh" is the root word.
#
# By presenting these distractors alongside the correct answer "Happy," the student must carefully analyze the structure of the word to determine the correct root word.
#
# === Question #2 === Question Type #3 === chain_of_thought_plus_sequential_rl ===
# ==> Step 1 result: 1. Word: Unhappy
#    - Root word: "happy"
#    - Incorrect Choice 1: "un"
#    - Incorrect Choice 2: "happi"
#    - Reasoning: "Unhappy" breaks down into the prefix "un-" and the root word "happy." This word is suitable as it clearly demonstrates the concept of a root word with a common prefix.
#
# 2. Word: Beautiful
#    - Root word: "beauty"
#    - Incorrect Choice 1: "ful"
#    - Incorrect Choice 2: "beauti"
#    - Reasoning: "Beautiful" consists of the root word "beauty" and the suffix "-ful." This word is suitable as it provides a clear example of a root word with a suffix attached.
#
# 3. Word: Teacher
#    - Root word: "teach"
#    - Incorrect Choice 1: "er"
#    - Incorrect Choice 2: "tea"
#    - Reasoning: "Teacher" is made up of the root word "teach" and the suffix "-er" indicating a person who does the action. This word is suitable as it showcases a root word with a suffix commonly added to form a new word.
#
# Final Word: Unhappy
# Reasoning: Among the three words listed, "Unhappy" is the best choice for a Grade 3-5 student learning about root words. It clearly demonstrates the concept of a root word with a common prefix attached. The breakdown of "un-" and "happy" makes it a straightforward example for students to identify the root word within a larger word.
#
# ==> Step 2 result: Step 2 (Draft Question):
#
# Question: What is the root word in the word "Frustrated"?
# A) Frustrate
# B) Strate
# C) Frust
#
# Correct Answer: A) Frustrate
#
# Chain-of-Thought:
# - The word "Frustrated" can be broken down into "Frustrate" and the suffix "-ed".
# - The root word in "Frustrated" is "Frustrate", as it is the base word from which other forms are derived.
# - To form the incorrect choices, variations of the root word were used to create confusion for the student.
#
# ==> Step 3 result: Updated Question:
# Question: What is the root word in the word "Frustrated"?
# A) Frustrate
# B) Strate
# C) Frust
# Correct Answer: A) Frustrate
#
# Reasoning for Distractors:
# - Choice B) Strate: This distractor might trick the student because it sounds similar to the word "Frustrated" and could be mistaken as the root word. However, "Strate" is not a valid root word in this context.
# - Choice C) Frust: This distractor could confuse the student as it is a close variation of the word "Frustrate", but it is not the root word.
#
# Final Question:
# Question: What is the root word in the word "Frustrated"?
# A) Frustrate
# B) Strate
# C) Frust
# Correct Answer: A) Frustrate
#
# ====== HERE IS THE FORBIDDEN_LIST: ['Unhappy']
#
#
# Generated Text from GPT-3.5 Model:
# Updated Question:
# Question: What is the root word in the word "Frustrated"?
# A) Frustrate
# B) Strate
# C) Frust
# Correct Answer: A) Frustrate
#
# Reasoning for Distractors:
# - Choice B) Strate: This distractor might trick the student because it sounds similar to the word "Frustrated" and could be mistaken as the root word. However, "Strate" is not a valid root word in this context.
# - Choice C) Frust: This distractor could confuse the student as it is a close variation of the word "Frustrate", but it is not the root word.
#
# Final Question:
# Question: What is the root word in the word "Frustrated"?
# A) Frustrate
# B) Strate
# C) Frust
# Correct Answer: A) Frustrate
#
# === Question #3 === Question Type #3 === chain_of_thought_plus_sequential_rl ===
# ==> Step 1 result: 1. Unhappy
#    - "Un-" is a common prefix meaning "not" or "opposite of" in this word.
#    - "Hap" is the root word meaning "luck" or "chance."
#    - "Y" is a suffix that changes the word to an adjective.
#
# 2. Beautiful
#    - "Beau-" is a prefix meaning "beautiful" or "good."
#    - "Ti" is not a recognizable root word.
#    - "Ful" is a suffix meaning "full of" or "having the quality of."
#
# 3. Teacher
#    - "Teach" is the root word meaning "to instruct or educate."
#    - "Er" is a suffix added to verbs to indicate a person who performs the action.
#    - "T" is not a recognizable root word.
#
# Final Word: Teacher
# Reasoning: I choose "Teacher" as the final word because it has a clear root word "teach" that students can easily identify. The other choices have prefixes or suffixes that may confuse students or make it harder for them to identify the root word. "Teacher" is straightforward and aligns well with the learning objective of identifying root words.
#
# ==> Step 2 result: Question: What is the root word in the word "Teacher"?
# A) Tea
# B) Teach
# C) Cher
#
# Correct Answer: B) Teach
#
# Chain-of-Thought:
# 1. Identify the word "Teacher" and determine its root word.
# 2. Break down the word into its components to find the base form.
# 3. Provide two other options that may sound plausible but are not the correct root word.
# 4. Ensure the correct answer is clear and stands out among the choices.
#
# ==> Step 3 result: Updated Question: What is the root word in the word "Teacher"?
#
# A) Tea
# B) Teach
# C) Cher
#
# Correct Answer: B) Teach
#
# Chain-of-Thought:
# - A) Tea: This option might trick the student because "Tea" is a common word that starts with the same letters as "Teacher", leading the student to think it's the root word.
# - C) Cher: This option might confuse the student as it contains a part of the word "Teacher" but is not the actual root word.
#
# By providing these distractors and the correct answer, the student will need to think critically about the word components to arrive at the correct root word.
#
# ====== HERE IS THE FORBIDDEN_LIST: ['Unhappy', 'Frustrated']
#
#
# Generated Text from GPT-3.5 Model:
# Updated Question: What is the root word in the word "Teacher"?
#
# A) Tea
# B) Teach
# C) Cher
#
# Correct Answer: B) Teach
#
# Chain-of-Thought:
# - A) Tea: This option might trick the student because "Tea" is a common word that starts with the same letters as "Teacher", leading the student to think it's the root word.
# - C) Cher: This option might confuse the student as it contains a part of the word "Teacher" but is not the actual root word.
#
# By providing these distractors and the correct answer, the student will need to think critically about the word components to arrive at the correct root word.
#
# === Question #1 === Question Type #4 === chain_of_thought_plus_sequential_rl ===
# ==> Step 1 result: In this case, we need to find a word that does NOT share the same prefix as the others in the given list. Looking at the words 'postmortem', 'postseason', and 'posture', we can see that the common prefix among them is "post-". So, we need to find a word that does not start with "post-".
#
# One possible word we can consider is "preheat". This word has a different prefix "pre-" compared to the common prefix "post-" in the other words. Therefore, "preheat" would be an appropriate choice for the question as it does not share the same prefix as the others.
#
# Another possible word we can consider is "misplace". This word has a prefix "mis-" which is different from the common prefix "post-" in the other words. Therefore, "misplace" would also be a suitable choice for the question as it does not share the same prefix as the others.
#
# Lastly, we can consider the word "foresee". This word starts with the prefix "fore-" which is different from the common prefix "post-" in the other words. Therefore, "foresee" would be another appropriate choice for the question as it does not share the same prefix as the others.
#
# Overall, any of these three words - "preheat", "misplace", or "foresee" - would be suitable choices for the question as they do not share the same prefix as the given words.
#
# ==> Step 2 result: Question: Which word does NOT share the same prefix as the others?
# A) postmortem
# B) postseason
# C) posture
#
# Correct answer: C) posture
#
# Chain-of-thought:
# 1. The given words are 'postmortem', 'postseason', and 'posture'.
# 2. The common prefix in the words is 'post-'.
# 3. The task is to identify the word that does NOT share the same prefix as the others.
# 4. By analyzing the words, it is evident that 'posture' does not have the prefix 'post-' like the other two words, making it the correct answer choice.
#
# ==> Step 3 result: Updated Question: Which word does NOT share the same prefix as the others?
# A) postmortem
# B) postseason
# C) posture
#
# Correct Answer: C) posture
#
# Reasoning for distractor A) postmortem: This distractor might trick the student because it contains the prefix 'post-', similar to the other words in the question. However, 'postmortem' is not the correct answer as it shares the same prefix as the other words.
#
# Reasoning for distractor B) postseason: This distractor might trick the student because it also contains the prefix 'post-', making it similar to the other words in the question. Despite this, 'postseason' is not the correct answer as it shares the same prefix as the other words.
#
# Final Question: Which word does NOT share the same prefix as the others?
# A) postmortem
# B) postseason
# C) posture
# Correct Answer: C) posture
#
# ====== HERE IS THE FORBIDDEN_LIST: []
#
#
# Generated Text from GPT-3.5 Model:
# Updated Question: Which word does NOT share the same prefix as the others?
# A) postmortem
# B) postseason
# C) posture
#
# Correct Answer: C) posture
#
# Reasoning for distractor A) postmortem: This distractor might trick the student because it contains the prefix 'post-', similar to the other words in the question. However, 'postmortem' is not the correct answer as it shares the same prefix as the other words.
#
# Reasoning for distractor B) postseason: This distractor might trick the student because it also contains the prefix 'post-', making it similar to the other words in the question. Despite this, 'postseason' is not the correct answer as it shares the same prefix as the other words.
#
# Final Question: Which word does NOT share the same prefix as the others?
# A) postmortem
# B) postseason
# C) posture
# Correct Answer: C) posture
#
# === Question #2 === Question Type #4 === chain_of_thought_plus_sequential_rl ===
# ==> Step 1 result: Step 2 (Generate Question):
# Now that we have chosen the word "postgraduate" as the word that does NOT share the same prefix as the others, we can proceed to generate the question.
#
# Question: Which word does NOT share the same prefix as the others?
# Choices:
# A) postscript
# B) postgraduate
# C) postpone
#
# This question is appropriate for students learning about morphemes because it tests their understanding of prefixes. The word "postgraduate" stands out as it has a different prefix compared to the other two words, making it the correct answer choice. The other two words, "postscript" and "postpone," share the prefix "post." This question challenges students to identify the word that does not follow the same pattern as the others, testing their knowledge of prefixes.
#
# ==> Step 2 result: Question: Which of the following words does NOT share the same prefix as the others?
#     A) postscript
#     B) postgraduate
#     C) postpone
#
# Correct Answer: C) postpone
#
# Chain-of-thought:
# 1. Identify the common prefix in the given words: 'post-'.
# 2. Choose a word that does not share the same prefix with the others, which is 'postpone'.
# 3. Ensure that the question aligns with the task difficulty of E, where the student needs to identify the word that does not follow the same pattern as the rest.
#
# ==> Step 3 result: Distractor A) postscript: This word starts with the same prefix 'post-' as the other words, potentially tricking the student into selecting it as the answer.
#
# Distractor B) postgraduate: Similar to distractor A, this word also shares the common prefix 'post-' with the other words, leading the student to consider it as a possible answer.
#
# Question: Which of the following words does NOT share the same prefix as the others?
# A) postscript
# B) postgraduate
# C) postpone
# Correct Answer: C) postpone
#
# ====== HERE IS THE FORBIDDEN_LIST: []
#
#
# Generated Text from GPT-3.5 Model:
# Distractor A) postscript: This word starts with the same prefix 'post-' as the other words, potentially tricking the student into selecting it as the answer.
#
# Distractor B) postgraduate: Similar to distractor A, this word also shares the common prefix 'post-' with the other words, leading the student to consider it as a possible answer.
#
# Question: Which of the following words does NOT share the same prefix as the others?
# A) postscript
# B) postgraduate
# C) postpone
# Correct Answer: C) postpone
#
# === Question #3 === Question Type #4 === chain_of_thought_plus_sequential_rl ===
# ==> Step 1 result: Choice 1: "outdo"
# This word shares the prefix "out-" with the other two words in the list ('outsmart', 'outlet'). It is not the correct answer for the question as it does share the same prefix as the others.
#
# Choice 2: "undo"
# This word does not share the prefix "out-" with the other two words in the list ('outsmart', 'outlet'). It is the correct answer for the question as it does not share the same prefix as the others.
#
# Choice 3: "outlet"
# This word shares the prefix "out-" with the other two words in the list ('outdo', 'outsmart'). It is not the correct answer for the question as it does share the same prefix as the others.
#
# ==> Step 2 result: Question: Which of the following words does NOT share the same prefix as the others? A) outdo B) outsmart C) outlet
#
# Chain-of-thought:
# - The word we have chosen is "Choice" which has the prefix "out".
# - The task difficulty is E, meaning the student should be able to identify simple prefixes.
# - The instruction requires us to create a question where the student has to identify the word that does NOT share the same prefix as the others.
# - Given the words 'outdo', 'outsmart', and 'outlet', all start with the prefix "out" except for one.
# - Therefore, the correct answer is the word that does NOT share the same prefix as the others.
#
# ==> Step 3 result: Distractor A: "outdo"
# Chain of thought: This distractor might trick the student because it starts with the prefix "out" just like the other words in the question, leading the student to think it is a valid choice.
#
# Distractor B: "outsmart"
# Chain of thought: This distractor might trick the student because it also starts with the prefix "out" just like the other words in the question, making it seem like a valid choice.
#
# Final question:
# Which of the following words does NOT share the same prefix as the others?
# A) outdo
# B) outsmart
# C) outlet
#
# Correct Answer: C) outlet
#
# ====== HERE IS THE FORBIDDEN_LIST: []
#
#
# Generated Text from GPT-3.5 Model:
# Distractor A: "outdo"
# Chain of thought: This distractor might trick the student because it starts with the prefix "out" just like the other words in the question, leading the student to think it is a valid choice.
#
# Distractor B: "outsmart"
# Chain of thought: This distractor might trick the student because it also starts with the prefix "out" just like the other words in the question, making it seem like a valid choice.
#
# Final question:
# Which of the following words does NOT share the same prefix as the others?
# A) outdo
# B) outsmart
# C) outlet
#
# Correct Answer: C) outlet
#
# === Question #1 === Question Type #5 === chain_of_thought_plus_sequential_rl ===
# ==> Step 1 result: Step 2 (Generate Question):
#
# Which word does NOT share the same suffix as the others?
#
# A) prepay
# B) prefix
# C) prejudge
#
# Correct Answer: B) prefix
#
# Explanation:
# - "prepay" and "prejudge" both share the suffix "-pre"
# - "prefix" does not share the same suffix as the other two words
#
# ==> Step 2 result: Question: Which word does NOT share the same suffix as the others?
# A) prejudge
# B) prepay
# C) prefix
#
# Chain-of-thought:
# 1. The word given is "step," so we need to come up with words related to morphemes that have different suffixes.
# 2. The words provided are 'prejudge', 'prepay', 'prefix'. These words all start with "pre" but have different suffixes.
# 3. By analyzing the words, we can see that 'prejudge' has the suffix "-judge," 'prepay' has the suffix "-pay," and 'prefix' has no suffix.
# 4. The question should ask the student to identify the word that does NOT share the same suffix as the others, which would be 'prefix' since it does not have a suffix.
#
# Correct Answer: C) prefix
#
# ==> Step 3 result: Updated Question: Which word does NOT share the same suffix as the others?
# A) prejudge
# B) prepay
# C) prefix
# Correct Answer: C) prefix
#
# Reasoning for Distractors:
# A) prejudge: This word might trick the student because it starts with "pre" just like the other words, but the suffix "-judge" is different from the other suffixes.
# B) prepay: This word might trick the student because it also starts with "pre" like the other words, but the suffix "-pay" is different from the other suffixes.
#
# ====== HERE IS THE FORBIDDEN_LIST: []
#
#
# Generated Text from GPT-3.5 Model:
# Updated Question: Which word does NOT share the same suffix as the others?
# A) prejudge
# B) prepay
# C) prefix
# Correct Answer: C) prefix
#
# Reasoning for Distractors:
# A) prejudge: This word might trick the student because it starts with "pre" just like the other words, but the suffix "-judge" is different from the other suffixes.
# B) prepay: This word might trick the student because it also starts with "pre" like the other words, but the suffix "-pay" is different from the other suffixes.
#
# === Question #2 === Question Type #5 === chain_of_thought_plus_sequential_rl ===
# ==> Step 1 result: Choice 1: "replay"
# This word does not share the same prefix as the others ('inter-'). It is suitable because it is a Grade 3-5 level word that fits the morphological concept of prefixes.
#
# Choice 2: "reaction"
# This word also does not share the same prefix as the others ('inter-'). It is appropriate as it is a common word that students in Grade 3-5 would be familiar with, and it fits the morphological concept of prefixes.
#
# Choice 3: "external"
# This word does not share the same prefix as the others ('inter-'). It is a suitable choice as it is a Grade 3-5 level word that fits the morphological concept of prefixes and suffixes.
#
# ==> Step 2 result: Question: Which of the following words does NOT share the same suffix as the others?
# A) interact
# B) interlock
# C) internal
#
# Correct Answer: C) internal
#
# Chain-of-thought:
# 1. Start with the word "choice" and think about a concept related to morphemes that can be applied to create a question.
# 2. Think about common morphemes such as prefixes and suffixes and how they can be used to differentiate words.
# 3. Identify the suffix in the given words 'interact', 'interlock', and 'internal' (in this case, it is "inter-").
# 4. Formulate the question asking the student to identify the word that does NOT share the same suffix as the others from the given words.
# 5. Provide answer choices that include the given words, making sure one stands out as not sharing the same suffix.
#
# ==> Step 3 result: Updated Question:
#
# Which of the following words does NOT share the same suffix as the others?
#
# A) interact
# B) interlock
# C) internal
#
# Correct Answer: C) internal
#
# Chain-of-thought for distractors:
# - A) interact: Might trick the student as it contains the common suffix "inter-," similar to the other words.
# - B) interlock: Might trick the student as it also contains the common suffix "inter-," similar to the other words.
#
# ====== HERE IS THE FORBIDDEN_LIST: []
#
#
# Generated Text from GPT-3.5 Model:
# Updated Question:
#
# Which of the following words does NOT share the same suffix as the others?
#
# A) interact
# B) interlock
# C) internal
#
# Correct Answer: C) internal
#
# Chain-of-thought for distractors:
# - A) interact: Might trick the student as it contains the common suffix "inter-," similar to the other words.
# - B) interlock: Might trick the student as it also contains the common suffix "inter-," similar to the other words.
#
# === Question #3 === Question Type #5 === chain_of_thought_plus_sequential_rl ===
# ==> Step 1 result: The word that does NOT share the same suffix as the others from the given words ['hyperextend', 'hypersensitive', 'hyperbole'] is "hyperbole."
# - "Hyperextend" and "hypersensitive" both end with the suffix "-extend" and "-sensitive" respectively, while "hyperbole" does not share the same suffix as the other two words. This makes "hyperbole" the appropriate choice for the question.
#
# ==> Step 2 result: Question: Which word does NOT share the same suffix as the others?
# A) hyperextend
# B) hypersensitive
# C) hyperbole
#
# Correct Answer: C) hyperbole
#
# Chain of Thought:
# 1. Identify the common suffix in the words: 'hyperextend', 'hypersensitive', 'hyperbole'.
# 2. Recognize that the suffix '-bole' is not present in 'hyperbole', setting it apart from the other two words.
# 3. Formulate the question to test the student's understanding of identifying morphemes by focusing on the suffixes of the given words.
#
# ==> Step 3 result: Updated Question: Which word does NOT share the same suffix as the others?
# A) hyperextend
# B) hypersensitive
# C) hyperbole
#
# Correct Answer: C) hyperbole
#
# Distractor A: hyperextend - This word contains the suffix '-extend' which might trick the student into thinking it is the odd one out due to the presence of a different suffix.
# Distractor B: hypersensitive - This word contains the suffix '-sensitive' which could mislead the student into choosing it as the answer based on the suffix difference.
#
# Chain of Thought:
# 1. Identify the common suffix in the words: 'hyperextend', 'hypersensitive', 'hyperbole'.
# 2. Recognize that the suffix '-bole' is not present in 'hyperbole', setting it apart from the other two words.
# 3. Formulate the question to test the student's understanding of identifying morphemes by focusing on the suffixes of the given words.
#
# ====== HERE IS THE FORBIDDEN_LIST: []
#
#
# Generated Text from GPT-3.5 Model:
# Updated Question: Which word does NOT share the same suffix as the others?
# A) hyperextend
# B) hypersensitive
# C) hyperbole
#
# Correct Answer: C) hyperbole
#
# Distractor A: hyperextend - This word contains the suffix '-extend' which might trick the student into thinking it is the odd one out due to the presence of a different suffix.
# Distractor B: hypersensitive - This word contains the suffix '-sensitive' which could mislead the student into choosing it as the answer based on the suffix difference.
#
# Chain of Thought:
# 1. Identify the common suffix in the words: 'hyperextend', 'hypersensitive', 'hyperbole'.
# 2. Recognize that the suffix '-bole' is not present in 'hyperbole', setting it apart from the other two words.
# 3. Formulate the question to test the student's understanding of identifying morphemes by focusing on the suffixes of the given words.
#
# === Question #1 === Question Type #6 === chain_of_thought_plus_sequential_rl ===
# ==> Step 1 result: 1. Word: Happy
#    Chain-of-thought: The word "happy" can be transformed by adding the suffix "-ness" to create the word "happiness", which means the state of being happy. This transformation involves changing the word from an adjective to a noun.
#
# 2. Word: Play
#    Chain-of-thought: The word "play" can be transformed by adding the prefix "re-" to create the word "replay", which means to play again. This transformation involves indicating a repetition of the action.
#
# 3. Word: Help
#    Chain-of-thought: The word "help" can be transformed by adding the suffix "-ful" to create the word "helpful", which means providing assistance or support. This transformation involves changing the word to describe someone or something that is helpful.
#
# Final Word: Happy
# Reasoning: I choose the word "happy" as the final word because the transformation involves a common and straightforward concept of adding a suffix to change the word to a related noun form. This transformation is suitable for Grade 3-5 students learning about word transformations.
#
# ==> Step 2 result: Step 3 (Draft Question):
#
# Question: What is the opposite of the word "Happy"?
# A) Sad
# B) Angry
# C) Excited
#
# Correct answer: A) Sad
#
# Chain-of-thought: The word "Happy" is a positive emotion, so the opposite of it would be a negative emotion. "Sad" is a common antonym for "Happy", making it the correct answer choice. "Angry" and "Excited" are emotions, but they do not directly represent the opposite of "Happy".
#
# ==> Step 3 result: Step 3 (Final Question):
#
# Question: What is the opposite of the word "Happy"?
# A) Excited
# B) Sad
# C) Angry
#
# Correct Answer: B) Sad
#
# Distractor A) "Excited" might trick the student because both "Happy" and "Excited" are positive emotions, leading the student to think they are related.
#
# Distractor C) "Angry" might trick the student as it is a negative emotion, but it does not directly represent the opposite of "Happy" which is a positive emotion.
#
# By shuffling the answer choices and providing explanations for the distractors, the final question is now ready for use.
#
# ====== HERE IS THE FORBIDDEN_LIST: []
#
#
# Generated Text from GPT-3.5 Model:
# Step 3 (Final Question):
#
# Question: What is the opposite of the word "Happy"?
# A) Excited
# B) Sad
# C) Angry
#
# Correct Answer: B) Sad
#
# Distractor A) "Excited" might trick the student because both "Happy" and "Excited" are positive emotions, leading the student to think they are related.
#
# Distractor C) "Angry" might trick the student as it is a negative emotion, but it does not directly represent the opposite of "Happy" which is a positive emotion.
#
# By shuffling the answer choices and providing explanations for the distractors, the final question is now ready for use.
#
# === Question #2 === Question Type #6 === chain_of_thought_plus_sequential_rl ===
# ==> Step 1 result: 1. Word: Act
#    - Choice 1: React (correct answer) - adding the prefix "re-" changes the word to mean to act again or in response to something.
#    - Choice 2: Active - changing the word to an adjective form.
#    - Choice 3: Actor - changing the word to a noun form.
#
# 2. Word: Play
#    - Choice 1: Replay (correct answer) - adding the prefix "re-" changes the word to mean to play again.
#    - Choice 2: Player - changing the word to a noun form.
#    - Choice 3: Playing - changing the word to a verb form.
#
# 3. Word: Happy
#    - Choice 1: Unhappy (correct answer) - adding the prefix "un-" changes the word to mean not happy.
#    - Choice 2: Happily - changing the word to an adverb form.
#    - Choice 3: Happiness - changing the word to a noun form.
#
# Final Word: Play
# I choose the word "Play" for the final question because it allows for clear and straightforward transformations with the prefix "re-". The correct answer "Replay" is easily understandable for students and fits well with the concept of word transformations.
#
# ==> Step 2 result: Step 3 (Draft Question):
# Question: Which transformation of the word "Play" means to perform a dramatic work on a stage?
# A) Player
# B) Played
# C) Playwright
#
# Correct Answer: C) Playwright
#
# Chain-of-Thought:
# - The word "Play" is given as the base word.
# - The task requires transforming the word to a new meaning related to performing a dramatic work on a stage.
# - "Player" could be a distractor as it refers to someone participating in a game or sport, not necessarily a dramatic performance.
# - "Played" is the past tense form of "Play," but it does not relate to performing a dramatic work on a stage.
# - "Playwright" is the correct answer as it refers to a person who writes plays, which are performed on stage.
#
# ==> Step 3 result: Step 3 (Draft Question):
# Question: Which transformation of the word "Play" means to perform a dramatic work on a stage?
# A) Player
# B) Played
# ...
# A) Act
# B) Rea
# C) Ion
# Correct Answer: A) Act
#
# The question accurately tests the morphological skill of identifying root words, aligning with question_type=3. The difficulty level is appropriate for Grade 3-5 students, given the word difficulty of 3 and task difficulty of M. The distractors are clearly different from the root word 'Act', making the question effective in assessing the student's understanding.
#
# === Question #2 === Question Type #3 === chain_of_thought_plus_role_chain ===
#
# Generated Text from GPT-3.5 Model:
# (1) Teacher Role:
# I want to create a question that focuses on identifying the root word in the word 'Unseen'. For students in grades 3-5, I need to ensure it's not too difficult. So, the question could be: "What is the root word in the word 'Unseen'?"
#
# (2) Student Role:
# As a student, I understand that the word 'Unseen' is made up of two parts - 'un' and 'seen'. I know that 'seen' is a word on its own, so that must be the root word in 'Unseen'. The other choices could be 'un' and 'see'.
#
# (3) Technometrician Role:
# Final Question: What is the root word in the word 'Unseen'?
# A) un
# B) see
# C) seen
# Correct Answer: C) seen
#
# This question accurately tests the morphological skill of identifying root words, and the difficulty level is appropriate for students in grades 3-5.
#
# === Question #3 === Question Type #3 === chain_of_thought_plus_role_chain ===
#
# Generated Text from GPT-3.5 Model:
# (1) Teacher Role:
# I would propose the following question for a Grade 3-5 student learning about root words:
#
# Question: What is the root word in 'Forearm'?
# A) Fore
# B) Arm
# C) Forearm
# Correct Answer: B) Arm
#
# I chose this question to test the student's understanding of root words by identifying the core word in 'Forearm', which is 'Arm'.
#
# (2) Student Role:
# The question seems clear to me as a student. The root word in 'Forearm' is 'Arm', so the correct answer should be B) Arm. A) Fore and C) Forearm are not the root words in this case.
#
# (3) Technometrician Role:
# Final Question: What is the root word in 'Forearm'?
# A) Fore
# B) Arm
# C) Forearm
# Correct Answer: B) Arm
#
# The question accurately tests the student's understanding of root words, specifically in the context of the word 'Forearm'. The difficulty level is appropriate for Grade 3-5 students, and the task aligns well with the morphological concept being tested.
#
# === Question #1 === Question Type #4 === chain_of_thought_plus_role_chain ===
#
# Generated Text from GPT-3.5 Model:
# (1) Teacher Role:
# I want to create a question that focuses on identifying words with different prefixes. Looking at the words 'forebode', 'forecast', and 'foreign', I see that 'fore' is a common prefix in the first two words. So, I will ask the students to identify the word that does NOT share the same prefix. The correct answer would be 'foreign' as it does not have the prefix 'fore' like the other two words.
#
# (2) Student Role:
# The question makes sense to me. The prefix 'fore' is in 'forebode' and 'forecast', but not in 'foreign'. So, the answer should be 'foreign' since it does not share the same prefix as the other two words.
#
# (3) Technometrician Role:
# Final Question: Which word does NOT share the same prefix as the others?
# A) forebode
# B) forecast
# C) foreign
# Correct Answer: C) foreign
# This question effectively tests the student's understanding of prefixes and aligns with the specified word difficulty and task difficulty.
#
# === Question #2 === Question Type #4 === chain_of_thought_plus_role_chain ===
#
# Generated Text from GPT-3.5 Model:
# (1) Teacher Role:
# I want to create a question that tests the student's understanding of prefixes. Looking at the words 'antibody', 'antithesis', and 'antics', I see that all of them start with the prefix 'anti-'. To make the question a bit more challenging, I will ask the student to identify the word that does NOT share the same prefix as the others. The correct answer will be 'antics', as it does not start with the prefix 'anti-'.
#
# (2) Student Role:
# The question asks me to find the word that does NOT share the same prefix as the others. Looking at the words 'antibody', 'antithesis', and 'antics', I can see that 'antibody' and 'antithesis' both start with the prefix 'anti-', but 'antics' does not. So, the correct answer is 'antics'.
#
# (3) Technometrician Role:
# Final Question: Which word does NOT share the same prefix as the others?
# A) antibody
# B) antithesis
# C) antics
# Correct Answer: C) antics
#
# This question aligns with the morphological objective of identifying prefixes, and the difficulty level is appropriate for students at a grade 3-5 level.
#
# === Question #3 === Question Type #4 === chain_of_thought_plus_role_chain ===
#
# Generated Text from GPT-3.5 Model:
# (1) Teacher Role:
# I will propose the following question: "Which word does NOT share the same prefix as the others?"
# - reassemble
# - reconnect
# - relic
#
# I chose these words because they all start with the prefix "re-", which means "again" or "back". However, "relic" is the word that does not share this prefix, so it should be the correct answer.
#
# (2) Student Role:
# As a student, I understand the question. The prefix "re-" means "again" or "back", and I can see that all the words start with this prefix except for "relic". Therefore, I would choose "relic" as the answer.
#
# (3) Technometrician Role:
# Final Question: Which word does NOT share the same prefix as the others?
# A) reassemble
# B) reconnect
# C) relic
# Correct Answer: C) relic
#
# The question accurately tests the morphological skill of identifying shared prefixes, and the difficulty level is appropriate for grade 3-5 students. The correct answer is clearly distinguishable from the distractors.
#
# === Question #1 === Question Type #5 === chain_of_thought_plus_role_chain ===
#
# Generated Text from GPT-3.5 Model:
# (1) Teacher Role:
# I will create a question focusing on identifying the word that does NOT share the same suffix as the others. Looking at the words 'overburden', 'overproduce', and 'overalls', I see that 'over' is a common prefix in all three words. The suffix in 'overburden' is 'burden', in 'overproduce' is 'produce', and in 'overalls' is 'alls'. So, the word 'overalls' is the one that does NOT share the same suffix as the others.
#
# (2) Student Role:
# The question is clear to me as a student. I understand that I need to find the word that does NOT share the same suffix as the others. Based on the explanation given by the teacher, I can see that 'overalls' is the word that doesn't have the same suffix as the others.
#
# (3) Technometrician Role:
# Final Question: Which word does NOT share the same suffix as the others?
# A) overburden
# B) overproduce
# C) overalls
# Correct Answer: C) overalls
#
# The question aligns well with the morphological concept of identifying suffixes. The word difficulty is appropriate for grade 3-5 students, and the task difficulty is moderate. The correct answer is clear and the distractors are relevant, making the question suitable for the intended grade level.
#
# === Question #2 === Question Type #5 === chain_of_thought_plus_role_chain ===
#
# Generated Text from GPT-3.5 Model:
# (1) Teacher Role:
# Considering the words 'subdue', 'subside', and 'subway', all of them share the suffix '-sub'. To create a question for students in grades 3-5, I will ask them to identify the word that does NOT share the same suffix as the others.
#
# (2) Student Role:
# The question is clear to me. I can see that 'subdue' and 'subside' both end with the suffix '-sub'. Therefore, the word 'subway' does not share the same suffix as the others.
#
# (3) Technometrician Role:
# Final Question: Which word does NOT share the same suffix as 'subdue' and 'subside'?
# A) subdue
# B) subside
# C) subway
# Correct Answer: C) subway
#
# This question aligns with the morphological concept of identifying suffixes and is suitable for grade 3-5 students. The difficulty level is appropriate for word_difficulty=3 and task_difficulty=M.
#
# === Question #3 === Question Type #5 === chain_of_thought_plus_role_chain ===
#
# Generated Text from GPT-3.5 Model:
# (1) Teacher Role:
# I want to create a question that challenges students' understanding of suffixes. Looking at the words 'pretest', 'preapprove', and 'president', I notice that they all start with 'pre-' but have different suffixes. My question will be: "Which word does NOT share the same suffix as the others?"
#
# (2) Student Role:
# As a student, I see that all three words start with 'pre-', but have different endings. 'pretest' ends with '-test', 'preapprove' ends with '-approve', and 'president' ends with '-dent'. So, the word that does NOT share the same suffix as the others is 'president'.
#
# (3) Technometrician Role:
# Final Question: Which word does NOT share the same suffix as the others?
# A) pretest
# B) preapprove
# C) president
# Correct Answer: C) president
#
# The question effectively tests the student's understanding of suffixes, and the difficulty level is appropriate for grades 3-5. The correct answer is clear and aligned with the objective of identifying the word with a different suffix.
#
# === Question #1 === Question Type #6 === chain_of_thought_plus_role_chain ===
#
# Generated Text from GPT-3.5 Model:
# (1) Teacher Role:
# Question: Transform the word 'Bark' to a new meaning by adding a suffix.
# Reasoning: I chose this question to focus on the concept of suffixes and word transformations. By asking students to add a suffix to the word 'Bark', they will have to think about how the meaning changes when a suffix is added to a base word.
#
# (2) Student Role:
# As a student, I understand the question. The word 'Bark' is the base word, and I need to add a suffix to transform it into a new meaning. The distractors should be suffixes that do not make sense when added to 'Bark'.
#
# (3) Technometrician Role:
# Final Question: Transform the word 'Bark' to a new meaning by adding a suffix.
# A) Barkful
# B) Barked
# C) Barker
# Correct Answer: A) Barkful
#
# I refined the question to focus on adding a suffix to the base word 'Bark'. The distractors 'Barked' and 'Barker' are incorrect as they do not form a new meaning by adding a suffix. 'Barkful' is the correct answer as it forms a new meaning by adding the suffix '-ful' to 'Bark'. This question aligns with the morphological objective and the specified difficulty levels.
#
# === Question #2 === Question Type #6 === chain_of_thought_plus_role_chain ===
#
# Generated Text from GPT-3.5 Model:
# (1) Teacher Role:
# Question: How can you transform the word 'Plant' to mean the act of putting something into the ground to grow?
# Reasoning: I chose this question to test students' understanding of word transformations related to plants. By using the base word 'Plant' and asking students to come up with a word that means putting something into the ground to grow, I am assessing their ability to apply morphological concepts. The incorrect choices will be related to other meanings of 'Plant' to provide a challenge for students.
#
# (2) Student Role:
# This question seems clear to me as a student. The word 'Plant' can be transformed to mean putting something into the ground to grow by adding the prefix 'Re-'. The incorrect choices might include unrelated meanings of 'Plant'.
#
# (3) Technometrician Role:
# Final Question: How can you transform the word 'Plant' to mean the act of putting something into the ground to grow?
# A) Unplant
# B) Preplant
# C) Replant
# Correct Answer: C) Replant
#
# === Question #3 === Question Type #6 === chain_of_thought_plus_role_chain ===
#
# Generated Text from GPT-3.5 Model:
# (1) Teacher Role:
# I want to create a question that challenges students to transform the word 'Stick' to a new meaning using a morphological concept. For this question, I will focus on adding a suffix to the word. The new word should have a different meaning than the original word.
#
# Question: What is the new meaning when you add the suffix "-y" to the word 'Stick'?
# A) Sticky
# B) Sticks
# C) Sticker
#
# (2) Student Role:
# As a student, I think the question is clear and straightforward. The suffix "-y" changes the meaning of the word 'Stick' to 'Sticky', which makes sense. The distractors 'Sticks' and 'Sticker' don't follow the same pattern of adding a suffix to change the meaning, so they are incorrect.
#
# (3) Technometrician Role:
# Final Question: What is the new meaning when you add the suffix "-y" to the word 'Stick'?
# A) Sticky
# B) Sticks
# C) Sticker
# Correct Answer: A) Sticky
#
# This question effectively tests the morphological skill of adding a suffix to a base word. The difficulty level is appropriate for word_difficulty=3 and task_difficulty=M. The distractors are clearly incorrect, aligning with the intended concept being tested.
#
# === Question #1 === Question Type #7 === chain_of_thought_plus_role_chain ===
#
# Generated Text from GPT-3.5 Model:
# Final Question: What does 'Outgrow' mean?
#       A) To grow bigger and taller
#       B) To stop growing
#       C) To exceed in growth
#       Correct Answer: A) To grow bigger and taller
#
# === Question #2 === Question Type #7 === chain_of_thought_plus_role_chain ===
#
# Generated Text from GPT-3.5 Model:
# (1) Teacher Role:
# I want to create a question that tests the student's understanding of affixed words. The word 'Postcard' consists of the root word 'Post' and the suffix 'card'. So, I will ask the students to select the correct meaning of 'Postcard' from three answer choices:
#
# 1. A card for writing messages sent after an event
# 2. A card for writing messages sent before an event
# 3. A card for writing messages sent during an event
#
# The correct answer is: A) A card for writing messages sent after an event
#
# (2) Student Role:
# As a student, I understand that 'Postcard' is made up of the root word 'Post' and the suffix 'card'. I know that 'Post' means after, so a 'Postcard' must be a card for writing messages sent after an event. Choice A seems correct to me. Choice B and C are obviously incorrect because they do not relate to the meaning of 'Post'.
#
# (3) Technometrician Role:
# Final Question: What is the correct meaning of the word 'Postcard'?
# A) A card for writing messages sent after an event
# B) A card for writing messages sent before an event
# C) A card for writing messages sent during an event
# Correct Answer: A) A card for writing messages sent after an event
#
# The question aligns well with the morphological concept of affixed words, as it focuses on the suffix 'card' added to the root 'Post'. The difficulty level is appropriate for grades 3-5 and the task difficulty is moderate. The distractors are clearly incorrect, making the correct answer easily identifiable.
#
# === Question #3 === Question Type #7 === chain_of_thought_plus_role_chain ===
#
# Generated Text from GPT-3.5 Model:
# (1) Teacher Role:
# I want to create a question that will test the student's understanding of affixed words. Since the word is 'Predict', which contains the prefix 'pre-', I will ask the student to choose the correct meaning of 'Predict' from the following choices:
#
# A) To look back on something
# B) To say what will happen in the future before it occurs
# C) To repeat something that has already been said
#
# I chose these options to test if the student can correctly identify the meaning of 'Predict' based on the prefix 'pre-' indicating something that happens before.
#
# (2) Student Role:
# As a student, I think the question is clear and focused on understanding the prefix 'pre-' in the word 'Predict'. Option B seems to be the correct choice as it aligns with the meaning of 'Predict' based on the prefix 'pre-' meaning before. Option A and C are clearly incorrect as they do not relate to the concept of predicting the future.
#
# (3) Technometrician Role:
# Final Question: What is the meaning of the word 'Predict'?
# A) To look back on something
# B) To say what will happen in the future before it occurs
# C) To repeat something that has already been said
# Correct Answer: B
#
# === Question #1 === Question Type #8 === chain_of_thought_plus_role_chain ===
# An error occurred with the GPT call: string longer than 2147483647 bytes
# No text returned by the model.
#
# === Question #2 === Question Type #8 === chain_of_thought_plus_role_chain ===
